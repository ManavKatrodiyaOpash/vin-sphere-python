# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/correctly_merged 1.csv')
data
# Out:
#         Unnamed: 0      chassisNumber    year             make trim  \
# 0                0  RKLBB9HE7F5115863  2015.0           TOYOTA   SE
# 1                1  JTFHX02POF0099797  2015.0           TOYOTA  GLX
# 2                2  JTFHX02P7F0094323  2015.0           TOYOTA   DX
# 3                3  JTFHXDGP7F0094373  2015.0           TOYOTA   DL
# 4                4  4T1BG22K01U789089  2001.0           TOYOTA  XLI
# ...            ...                ...     ...              ...  ...
# 995042      995042  HY2PEAND0PB000238  2023.0           BIMOTA  NaN
# 995043      995043  LNGPCMXJ9PL305272  2023.0           APULUO  NaN
# 995044      995044  LURJAVBM8PA024843  2023.0            CHERY  STD
# 995045      995045  7KGTC2C48NR003646  2022.0  ELECTRIC MOTION  NaN
# 995046      995046  LX6TK334XS2510023  2025.0         CHANGHUA  NaN
#
#           bodyType regionalSpec  cylinders          color  origin  weightInKg  \
# ...

# %%
data = data.drop(columns=['make', 'trim', 'bodyType', 'cylinders', 'color'])

# %%
data
# Out:
#         Unnamed: 0      chassisNumber    year regionalSpec  origin  \
# 0                0  RKLBB9HE7F5115863  2015.0          GCC  Taiwan
# 1                1  JTFHX02POF0099797  2015.0          GCC   Japan
# 2                2  JTFHX02P7F0094323  2015.0          GCC   Japan
# 3                3  JTFHXDGP7F0094373  2015.0          GCC   Japan
# 4                4  4T1BG22K01U789089  2001.0      Non-GCC     USA
# ...            ...                ...     ...          ...     ...
# 995042      995042  HY2PEAND0PB000238  2023.0          GCC   China
# 995043      995043  LNGPCMXJ9PL305272  2023.0          GCC   China
# 995044      995044  LURJAVBM8PA024843  2023.0          GCC   China
# 995045      995045  7KGTC2C48NR003646  2022.0          GCC     USA
# 995046      995046  LX6TK334XS2510023  2025.0          GCC   China
#
#         weightInKg  noOfPassengers     make_grouped model_final  \
# 0           1000.0               5           TOYOTA     COROLLA
# ...

# %%
data = data.drop(columns=['body_type_conflict'])

# %%
data
# Out:
#         Unnamed: 0      chassisNumber    year regionalSpec  origin  \
# 0                0  RKLBB9HE7F5115863  2015.0          GCC  Taiwan
# 1                1  JTFHX02POF0099797  2015.0          GCC   Japan
# 2                2  JTFHX02P7F0094323  2015.0          GCC   Japan
# 3                3  JTFHXDGP7F0094373  2015.0          GCC   Japan
# 4                4  4T1BG22K01U789089  2001.0      Non-GCC     USA
# ...            ...                ...     ...          ...     ...
# 995042      995042  HY2PEAND0PB000238  2023.0          GCC   China
# 995043      995043  LNGPCMXJ9PL305272  2023.0          GCC   China
# 995044      995044  LURJAVBM8PA024843  2023.0          GCC   China
# 995045      995045  7KGTC2C48NR003646  2022.0          GCC     USA
# 995046      995046  LX6TK334XS2510023  2025.0          GCC   China
#
#         weightInKg  noOfPassengers     make_grouped model_final  \
# 0           1000.0               5           TOYOTA     COROLLA
# ...

# %%
data = data.to_csv("../Data/Cleaned.csv")
