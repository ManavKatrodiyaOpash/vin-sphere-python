# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv(r"..\data\data_methaq(2.0).csv")
data
# Out:
#              chassisNumber    year             make            model trim  \
# 0        RKLBB9HE7F5115863  2015.0           TOYOTA          COROLLA   SE
# 1        JTFHX02POF0099797  2015.0           TOYOTA            HIACE  GLX
# 2        JTFHX02P7F0094323  2015.0           TOYOTA            HIACE   DX
# 3        JTFHXDGP7F0094373  2015.0           TOYOTA            HILUX   DL
# 4        4T1BG22K01U789089  2001.0           TOYOTA            CAMRY  XLI
# ...                    ...     ...              ...              ...  ...
# 1009599  LNGPCMXJ9PL305272  2023.0           APULUO  APULUO AP200 4H  NaN
# 1009600  LURJAVBM8PA024843  2023.0            AIQAR             EQ 1  STD
# 1009601  7KGTC2C48NR003646  2022.0  Electric Motion            ePure  NaN
# 1009602  LX6TK334XS2510023  2025.0        CHANGHUA         CH150T-34  NaN
# 1009603         MI76734700  2015.0          MANITOU       MTX1740SLT   GL
#
#                    bodyType regionalSpec  cylinders            color   origin  \
# ...

# %%
data["chassis_len"] = data["chassisNumber"].str.len()
data["pos10"] = data["chassisNumber"].str[9]

is_standard = (data["chassis_len"] == 17) & (~data["pos10"].isin(['I', 'O', 'Q', 'U', 'Z', '0']))
data = data[is_standard]
data
# Out:
#              chassisNumber    year             make            model trim  \
# 0        RKLBB9HE7F5115863  2015.0           TOYOTA          COROLLA   SE
# 1        JTFHX02POF0099797  2015.0           TOYOTA            HIACE  GLX
# 2        JTFHX02P7F0094323  2015.0           TOYOTA            HIACE   DX
# 3        JTFHXDGP7F0094373  2015.0           TOYOTA            HILUX   DL
# 4        4T1BG22K01U789089  2001.0           TOYOTA            CAMRY  XLI
# ...                    ...     ...              ...              ...  ...
# 1009598  HY2PEAND0PB000238  2023.0           Bimota       AYED250N 3  NaN
# 1009599  LNGPCMXJ9PL305272  2023.0           APULUO  APULUO AP200 4H  NaN
# 1009600  LURJAVBM8PA024843  2023.0            AIQAR             EQ 1  STD
# 1009601  7KGTC2C48NR003646  2022.0  Electric Motion            ePure  NaN
# 1009602  LX6TK334XS2510023  2025.0        CHANGHUA         CH150T-34  NaN
#
#                    bodyType regionalSpec  cylinders            color   origin  \
# ...

# %%
print(", ".join(map(str, data['origin'].unique())))
# Out:
# Taiwan, Japan, JAPAN, Thailand, Australia, THAILAND, AUSTRALIA, AMERICA, United States, Indonesia, INDONESIA, America, USA, Canada, TAIWAN, Germany, Austria, CANADA, CHINA, Turkey, GERMANY, UNITED STATES VIRGIN, Mexico, Republic of Turkiye, UNITED STATES, China, Spain, INDIA, India, SOUTH KOREA, United Kingdom, UAE, nan, TAHITIAN, United States Virgin Islands, UNITED ARAB EMIRATES, UNITED KINGDOM, MEXICO, UNITED STATES VIRGIN ISLANDS, Yemen, United Nations, ANDORRA, 000, Poland, Iran, France, تايلاند, American Samoa, Guam (USA), PAPUA NEW GUINEA, FRANCE, REPUBLIC OF TURKIYE, Sudan, Greece, Talwan, South Korea, JINDONESIA, 00, United Arab Emirates, SWEDEN, 0, Andorra, EMIRATES, AFGHANISTAN, GCC, Emirates, تايلند, Taiwan (Chinese Taipei for IOC), INDIAN, AUSTRIA, Sweden, Others, New Zealand, تركيا, JAPAN , Pakistan, NAYON, استراليا, GUINEA, UNITED NATIONS, UNKNOWN, JAMERICA, U.S.A, Tabun, Macau, US, Light Vehicle, NORTH AMERICA, EGYPT, Estonia, SOUTH AFRICA, ITALY, Unknown, JPAN, Dubai
# ...

# %%
print(", ".join(map(str, data['origin'].unique())))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(", ".join(map(str, data['origin'].nunique())))
#
# TypeError: 'int' object is not iterable

# %%
import pandas as pd
import numpy as np
import re

# ==========================================================
# COUNTRY NORMALIZATION
# ==========================================================

COUNTRY_MAPPING = {

    # USA
    "USA": "USA",
    "US": "USA",
    "U.S.A": "USA",
    "UNITED STATES": "USA",
    "UNITED STATES OF AMERICA": "USA",
    "UNITED STATE": "USA",
    "AMERICA": "USA",
    "AMERICAN": "USA",
    "AMERIC": "USA",
    "AMRICA": "USA",
    "AMIRICA": "USA",
    "AMWERICA": "USA",
    "JAMERICA": "USA",
    "AMERESA": "USA",
    "امريكا": "USA",
    "الولايات المتحدة": "USA",

    # Japan
    "JAPAN": "JAPAN",
    "JAPANN": "JAPAN",
    "JAPANE": "JAPAN",
    "JAPN": "JAPAN",
    "JPAN": "JAPAN",
    "JAPA": "JAPAN",
    "JAP": "JAPAN",
    "JA": "JAPAN",
    "J": "JAPAN",
    "JABAN": "JAPAN",
    "JARAN": "JAPAN",
    "JAAN": "JAPAN",
    "JAOAN": "JAPAN",
    "SAPAN": "JAPAN",
    "TAPAN": "JAPAN",
    "CAPAN": "JAPAN",
    "DAPAN": "JAPAN",
    "UAPAN": "JAPAN",
    "APAN": "JAPAN",
    "J. PAN": "JAPAN",
    "اليابان": "JAPAN",

    # Taiwan
    "TAIWAN": "TAIWAN",
    "TALWAN": "TAIWAN",
    "TAIMAN": "TAIWAN",
    "TAIWAN (CHINESE TAIPEI)": "TAIWAN",
    "TAIWAN (CHINESE TAIPEI FOR IOC)": "TAIWAN",
    "TAIWAN (PROVINCE OF CHINA)": "TAIWAN",
    "TAI": "TAIWAN",
    "BAIWAN": "TAIWAN",
    "LIWAN": "TAIWAN",
    "TABUN": "TAIWAN",
    "TAINAN": "TAIWAN",
    "تايون": "TAIWAN",

    # Thailand
    "THAILAND": "THAILAND",
    "TAILAND": "THAILAND",
    "THALLAND": "THAILAND",
    "THALAND": "THAILAND",
    "THILAND": "THAILAND",
    "HAILAND": "THAILAND",
    "THE THAILAND": "THAILAND",
    "PRE THAILAND": "THAILAND",
    "تايلاند": "THAILAND",
    "تایلاند": "THAILAND",

    # UAE
    "UAE": "UAE",
    "U.A.E.": "UAE",
    "AE": "UAE",
    "EMIRATES": "UAE",
    "EMRATES": "UAE",
    "UNITED ARAB EMIRATES": "UAE",
    "UNITED EMIRATES": "UAE",
    "UNITED ARAB": "UAE",
    "DUBAI": "UAE",
    "ABU DHABI": "UAE",
    "ABU ظبي": "UAE",
    "الإمارات العربية المتحدة": "UAE",
    "أبو ظبي": "UAE",

    # South Korea
    "KOREA": "SOUTH KOREA",
    "KOREAN": "SOUTH KOREA",
    "SOUTH KOREA": "SOUTH KOREA",
    "SOUTHKOREA": "SOUTH KOREA",
    "SOUTH KORIA": "SOUTH KOREA",
    "SOUTH COREA": "SOUTH KOREA",
    "SOUTH KOR": "SOUTH KOREA",
    "SOUTH K": "SOUTH KOREA",
    "KOREA SOUTH": "SOUTH KOREA",
    "REPUBLIC OF KOREA": "SOUTH KOREA",
    "REPUBLIC OF SOUTH KOREA": "SOUTH KOREA",
    "KOREA (REPUBLIC OF SOUTH KOREA)": "SOUTH KOREA",
    "KOREA (REPUBLIC OF)": "SOUTH KOREA",
    "كوريا الجنوبية": "SOUTH KOREA",

    # China
    "CHINA": "CHINA",
    "CHINA1": "CHINA",
    "CHINA 1": "CHINA",
    "CHAIN": "CHINA",
    "CHINE": "CHINA",
    "CIDINA": "CHINA",
    "HINA": "CHINA",
    "الصين": "CHINA",

    # Turkey
    "TURKEY": "TURKEY",
    "TURKIYE": "TURKEY",
    "REPUBLIC OF TURKIYE": "TURKEY",
    "REPUBLIC OF TUR": "TURKEY",
    "تركيا": "TURKEY",

    # UK
    "UK": "UNITED KINGDOM",
    "UNITED KINGDOM": "UNITED KINGDOM",
    "UNITED KINGDOM (UK)": "UNITED KINGDOM",
    "UNITED KINGDOM (GREAT BRITAIN)": "UNITED KINGDOM",
    "GREAT BRITAIN": "UNITED KINGDOM",
    "BRITAIN": "UNITED KINGDOM",
    "BRITISH": "UNITED KINGDOM",
    "BRITSH": "UNITED KINGDOM",
    "BRTISH": "UNITED KINGDOM",
    "بريطانيا": "UNITED KINGDOM",

    # Germany
    "GERMANY": "GERMANY",
    "GERMAN": "GERMANY",
    "GER": "GERMANY",
    "JERMANY": "GERMANY",
    "GERMANY (DEUTSCHLAND)": "GERMANY",
    "GERMANY ": "GERMANY",
    "المانيا": "GERMANY",

    # Australia
    "AUSTRALIA": "AUSTRALIA",
    "AUSTRALLA": "AUSTRALIA",
    "AUSTLIA": "AUSTRALIA",
    "AUSTRIAL": "AUSTRALIA",
    "FAUSTRALIA": "AUSTRALIA",
    "استراليا": "AUSTRALIA",

    # Indonesia
    "INDONESIA": "INDONESIA",
    "JINDONESIA": "INDONESIA",
    "FINDONESIA": "INDONESIA",

    # India
    "INDIA": "INDIA",
    "INCIA": "INDIA",
    "INDIAN": "INDIA",
    "JINDIA": "INDIA",
    "الهند": "INDIA",

    # Mexico
    "MEXICO": "MEXICO",
    "MAXICO": "MEXICO",
    "MEXICA": "MEXICO",
    "MEC": "MEXICO",
    "MEX": "MEXICO",
    "المكسيك": "MEXICO",
}

INVALID_COUNTRIES = {
    "", "-", ".", "`",
    "0", "00", "000", "0000", "00000",
    "1", "2", "4", "11", "12",
    "17750", "213", "22960", "26261",
    "3001", "72058", "75844", "90358",
    "123", "16394", "5454",

    "NAN",
    "NA",
    "NONE",
    "UNKNOWN",
    "NOT SPECIFIED",
    "UNDEFINED",

    "ORIGIN",
    "COUNTRY OF ORIGIN",
    "COUNTRY OF MANUFACTURE",

    "ASIA",
    "ASIAN",
    "AFRICAN COUNTRIES",
    "ARABIC COUNTRIES",
    "EUROPE",
    "EUROPE UNION",
    "EUROPEAN UNION",
    "NORTH AMERICA",
    "N AMERICAN",
    "SOUTH AMERICA",
    "S AMERICAN",

    "GCC",
    "NON GCC",
    "NON-GCC",
    "NON-GCC STANDARD",
    "GCC STANDARD",

    "OTHERS",
    "OTHER",

    "TOYOTA",
    "HONDA",

    "WHITE",
    "SILVER",
    "ORANGE",

    "ELECTRIC",
    "SALES",
    "MOTORCYCLE"
}

# ==========================================================
# CLEAN FUNCTION
# ==========================================================

def clean_country(data: pd.DataFrame,
                  column: str = "origin",
                  rare_threshold: int = 10) -> pd.DataFrame:

    data = data.copy()

    data[column] = (
        data[column]
        .astype(str)
        .str.upper()
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
    )

    data[column] = data[column].replace(COUNTRY_MAPPING)

    data.loc[
        data[column].isin(INVALID_COUNTRIES),
        column
    ] = np.nan

    # Remove purely numeric values
    data.loc[
        data[column].str.match(r"^\d+$", na=False),
        column
    ] = np.nan

    # Group very rare values
    counts = data[column].value_counts()

    rare_values = counts[counts < rare_threshold].index

    data.loc[
        data[column].isin(rare_values),
        column
    ] = "OTHER"

    return data


# ==========================================================
# APPLY
# ==========================================================

data = clean_country(
    data,
    column="origin",
    rare_threshold=10
)

print(f"Unique Countries: {data['origin'].nunique()}")

print(
    data["origin"]
    .value_counts(dropna=False)
    .head(100)
)
# Out:
# Unique Countries: 65
# origin
# JAPAN                   355636
# USA                     162965
# NaN                      83946
# SOUTH KOREA              59957
# CHINA                    53941
#                          ...
# SAUDI ARABIA                13
# SOUTH AMERICAN              13
# UNITED STATES VIRGIN        12
# ANDORRA                     10
# MYANMAR                     10
# Name: count, Length: 66, dtype: int64

# %%
# 1. World Manufacturer Identifier (WMI)
data["WMI"] = data["chassisNumber"].str[0:3]
data["pos1"] = data["chassisNumber"].str[0]
data["pos2"] = data["chassisNumber"].str[1]
data["pos3"] = data["chassisNumber"].str[2]

# 2. Vehicle Descriptor Section (VDS)
data["VDS"] = data["chassisNumber"].str[3:9]  # Standard VIN uses positions 4-9 (index 3:9)
data["pos4"] = data["chassisNumber"].str[3]
data["pos5"] = data["chassisNumber"].str[4]
data["pos6"] = data["chassisNumber"].str[5]
data["pos7"] = data["chassisNumber"].str[6]
data["pos8"] = data["chassisNumber"].str[7]
data["pos9"] = data["chassisNumber"].str[8]  # Check Digit

# 3. Vehicle Identifier Section (VIS)
data["VIS"] = data["chassisNumber"].str[9:17]  # Standard VIN uses positions 10-17 (index 9:17)
data["Model_Year"] = data["chassisNumber"].str[9]  # Model Year
data["Plant_Code"] = data["chassisNumber"].str[10]  # Plant Code

# 4. Production Serial Number (Last 6 digits of VIS)
data["Serial_Number"] = data["chassisNumber"].str[11:17]

# %%
data
# Out:
#              chassisNumber    year             make            model trim  \
# 0        RKLBB9HE7F5115863  2015.0           TOYOTA          COROLLA   SE
# 1        JTFHX02POF0099797  2015.0           TOYOTA            HIACE  GLX
# 2        JTFHX02P7F0094323  2015.0           TOYOTA            HIACE   DX
# 3        JTFHXDGP7F0094373  2015.0           TOYOTA            HILUX   DL
# 4        4T1BG22K01U789089  2001.0           TOYOTA            CAMRY  XLI
# ...                    ...     ...              ...              ...  ...
# 1009598  HY2PEAND0PB000238  2023.0           Bimota       AYED250N 3  NaN
# 1009599  LNGPCMXJ9PL305272  2023.0           APULUO  APULUO AP200 4H  NaN
# 1009600  LURJAVBM8PA024843  2023.0            AIQAR             EQ 1  STD
# 1009601  7KGTC2C48NR003646  2022.0  Electric Motion            ePure  NaN
# 1009602  LX6TK334XS2510023  2025.0        CHANGHUA         CH150T-34  NaN
#
#                    bodyType regionalSpec  cylinders            color  origin  \
# ...

# %%
origin_mapping = {
    "1": "USA",
    "4": "USA",
    "5": "USA",
    "2": "CANADA",
    "3": "MEXICO",
    "J": "JAPAN",
    "K": "SOUTH KOREA",
    "W": "GERMANY",
    "Z": "ITALY",
    "S": "UNITED KINGDOM",
    "Y": "SWEDEN / FINLAND",
    "L": "CHINA",
    "M": "INDIA",
    "V": "FRANCE / SPAIN",
    "T": "SWITZERLAND",
    "R": "TAIWAN",
    "9": "BRAZIL"
}

# %%
data["origin"] = data["pos1"].map(origin_mapping).fillna(data["origin"])

# %%
data
# Out:
#              chassisNumber    year             make            model trim  \
# 0        RKLBB9HE7F5115863  2015.0           TOYOTA          COROLLA   SE
# 1        JTFHX02POF0099797  2015.0           TOYOTA            HIACE  GLX
# 2        JTFHX02P7F0094323  2015.0           TOYOTA            HIACE   DX
# 3        JTFHXDGP7F0094373  2015.0           TOYOTA            HILUX   DL
# 4        4T1BG22K01U789089  2001.0           TOYOTA            CAMRY  XLI
# ...                    ...     ...              ...              ...  ...
# 1009598  HY2PEAND0PB000238  2023.0           Bimota       AYED250N 3  NaN
# 1009599  LNGPCMXJ9PL305272  2023.0           APULUO  APULUO AP200 4H  NaN
# 1009600  LURJAVBM8PA024843  2023.0            AIQAR             EQ 1  STD
# 1009601  7KGTC2C48NR003646  2022.0  Electric Motion            ePure  NaN
# 1009602  LX6TK334XS2510023  2025.0        CHANGHUA         CH150T-34  NaN
#
#                    bodyType regionalSpec  cylinders            color  origin  \
# ...

# %%
print(", ".join(map(str, data['model'].unique())))
# Out:
# COROLLA, HIACE, HILUX, CAMRY, LAND CRUISER, YARIS, FJ CRUISER, RAV4, TUNDRA, AVALON, FORTUNER, COASTER, INNOVA, SIENNA, TACOMA, PRADO, LAND CRUISER PICK UP, RUSH, PRIUS, AVANZA, SEQUOIA, SUPRA, AURION, ECHO, PREVIA, BZ4X, COROLLA CROSS, C-HR, XA, GRANVIA, VELOZ, RAIZE, iQ, TOYOTA CAMRY, LAND CRUISER PICKUP 70, FJ, CROWN, 86, 4RUNNER, COROLLA 1.6, URBAN CRUISER, SCION, SOLARA, IQ, HIGHLANDER, OTHERS, DYNA, LAND CRUISE, LAND CRUISER 70, TERCEL, LITEACE, MATRIX, RAV 4, GR86, LEVIN, ZELAS, ALPHARD, TOYOTA VELOZ, T 300, 4 RUNNER, TOYOTA LAND CRUISER, COROLLA 1.3, LAND CRUISER PRADO, CRESSIDA, LAND CRUISER VXR, CROWN KLUGER, 2023, بريفيا, TAKOMA, 2009, كامري, TOYOTA PRIUS, TOYOTA ALTIS, ALTIS, استیشن, TOYOTA COROLLA, TOYOTA TACOMA, JUSTIN BIEBER X VESPA 150 E5 GSO (SCOOTER), COROLLA 1.8, BZ3X, COROLLA SEDAN, بيك اب كابينه مزدوجه, 26HX DC 4X4P2.7LAT, COROLLA 1.5, LAND CRUISER PICK UP CARGO, SALOON, PICK UP, RUMION, MR2, TOYOTA, WISH, 25 LP SC4X44.0L MT, HD 4X4, FLTRXS, DAINA, TANDRA, LAND C
# ...

# %%
import pandas as pd
import numpy as np

# ==========================================================
# TOYOTA MODEL NORMALIZATION
# ==========================================================

MODEL_MAPPING = {

    # Corolla
    "TOYOTA COROLLA": "COROLLA",
    "COROLLA 1.3": "COROLLA",
    "COROLLA 1.5": "COROLLA",
    "COROLLA 1.6": "COROLLA",
    "COROLLA 1.8": "COROLLA",
    "COROLLA LI": "COROLLA",
    "COROLLA SEDAN": "COROLLA",
    "COROLLA SEDAN / HATCH": "COROLLA",
    "COROLLA 1.5L/HATCHBACK": "COROLLA",
    "COROLLA 1.6/SEDAN": "COROLLA",
    "TOYOTA COROLLA 1.6": "COROLLA",
    "TOYOTA COROLLA 1.8": "COROLLA",
    "TOYOTA COROLLA 2.0": "COROLLA",
    "كورولا": "COROLLA",
    "كورولا 1.3": "COROLLA",
    "كورولا 1.8": "COROLLA",

    # Camry
    "TOYOTA CAMRY": "CAMRY",
    "CAMRY HYBRID": "CAMRY",
    "CAMRY SOLARA": "CAMRY",
    "كامري": "CAMRY",
    "كامرى": "CAMRY",

    # Hilux
    "HAI LUX": "HILUX",
    "HI LUX": "HILUX",
    "TOYOTA HILUX": "HILUX",
    "HILUX RE": "HILUX",
    "HILUX ADVENTURE": "HILUX",
    "هاي لوكس": "HILUX",
    "هايلوكس": "HILUX",

    # Tacoma
    "TOYOTA TACOMA": "TACOMA",
    "TOKOMA": "TACOMA",
    "TAKOMA": "TACOMA",
    "TAKOMA PICK UP CARGO": "TACOMA",
    "TACOMA (PICK UP)": "TACOMA",
    "تاكوما": "TACOMA",

    # Tundra
    "TOYOTA TUNDRA": "TUNDRA",
    "TANDRA": "TUNDRA",
    "TUNDRA (PICK UP)": "TUNDRA",
    "TANDRA PICK UP DOUBLE CABIN": "TUNDRA",

    # Land Cruiser
    "TOYOTA LAND CRUISER": "LAND CRUISER",
    "LAND CRUISE": "LAND CRUISER",
    "LAND CRUISER GX": "LAND CRUISER",
    "LAND CRUISER GXR": "LAND CRUISER",
    "LAND CRUISER VXR": "LAND CRUISER",
    "LAND CRUISER / STATION": "LAND CRUISER",
    "LAND CRUISER PICKUP": "LAND CRUISER",
    "LAND CRUISER PICK UP": "LAND CRUISER",
    "LAND CRUISER PICKUP 70": "LAND CRUISER",
    "LAND CRUISER 70": "LAND CRUISER",
    "LAND CRUISER PICK UP CARGO": "LAND CRUISER",
    "LAND CRUISER/PICK UP CARGO": "LAND CRUISER",
    "LAND CRUISER - PICK UP CARGO": "LAND CRUISER",
    "LAND CRUISER SINGLE-CABIN PICK UP": "LAND CRUISER",
    "LAND CRUISER SINGLE-CABIN PICK": "LAND CRUISER",
    "LAND CRUISER/STD EX PICKUP": "LAND CRUISER",
    "لاند كروزر": "LAND CRUISER",

    # Prado
    "LAND CRUISER PRADO": "PRADO",
    "TOYOTA PRADO": "PRADO",
    "PRADO GX": "PRADO",
    "برادو": "PRADO",

    # RAV4
    "RAV 4": "RAV4",
    "RAV4 LE CAR": "RAV4",

    # Prius
    "TOYOTA PRIUS": "PRIUS",

    # Altis
    "TOYOTA ALTIS": "ALTIS",

    # Veloz
    "TOYOTA VELOZ": "VELOZ",

    # Scion
    "SICION": "SCION",
    "TOYOTA SCION": "SCION",

    # MR2
    "MR 2": "MR2",

    # 4Runner
    "4 RUNNER": "4RUNNER",
    "FORERUNNER": "4RUNNER",
    "RUNNER": "4RUNNER",
    "TOYOTA 4RUNNER": "4RUNNER",

    # C-HR
    "CHR": "C-HR",

    # GR86
    "TOYOTA 86": "GR86",
    "86": "GR86",

    # Hiace
    "HI ACE": "HIACE",
    "HIACE ": "HIACE",
    "TOYOTA HIACE": "HIACE",

    # Sienna
    "SIENA": "SIENNA",
    "SENA": "SIENNA",
    "SIENNA VAN": "SIENNA",
    "SIENNA(VAN)": "SIENNA",
    "SENA VAN PASSENGER": "SIENNA",

    # LiteAce
    "LITE ACE": "LITEACE",

    # Avanza
    "افنزا": "AVANZA",

    # BZ4X
    "BZ 4": "BZ4X",
    "BZ46": "BZ4X",

    # Dyna
    "DAINA": "DYNA",
}

INVALID_MODELS = {
    "NAN",
    "",
    " ",
    "-",
    "TOYOTA",
    "OTHERS",
    "OTHER",
    "2022",
    "2023",
    "2024",
    "2016",
    "2014",
    "2012",
    "2009",
    "2008",
    "1999",
    "1998",
}

def clean_model(data: pd.DataFrame,
                column: str = "model",
                rare_threshold: int = 10):

    data = data.copy()

    data[column] = (
        data[column]
        .astype(str)
        .str.upper()
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
    )

    data[column] = data[column].replace(MODEL_MAPPING)

    data.loc[data[column].isin(INVALID_MODELS), column] = np.nan

    # Group rare models
    counts = data[column].value_counts()
    rare_models = counts[counts < rare_threshold].index

    data.loc[
        data[column].isin(rare_models),
        column
    ] = "OTHER"

    return data


# ==========================================================
# APPLY
# ==========================================================

data = clean_model(
    data,
    column="model",
    rare_threshold=10
)

print(f"Unique Models: {data['model'].nunique()}")
print(data["model"].value_counts(dropna=False).head(100))
# Out:
# Unique Models: 1380
# model
# CAMRY           51746
# PATROL          48340
# ALTIMA          42043
# COROLLA         38122
# LAND CRUISER    33588
#                 ...
# OUTLANDER        2067
# NAVARA           2066
# DUSTER           2051
# PREVIA           2032
# VELOSTER         2019
# Name: count, Length: 100, dtype: int64

# %%
print(", ".join(map(str, data['make'].unique())))
# Out:
# TOYOTA, NISSAN, LEXUS, MITSUBISHI, HONDA, HYUNDAI, KIA, MERCEDES BENZ, CHEVROLET, FORD, TESLA, BMW, GMC, LAND ROVER, SUZUKI, VOLKSWAGEN, JETOUR, MAZDA, JEEP, INFINITI, MG, Nissan, BYD, DODGE, Toyota, AUDI, RENAULT, CHANGAN, PORSCHE, PEUGEOT, ROX, CADILLAC, MINI, GEELY, Lexus, RAM, LINCOLN, ISUZU, BAJAJ, JAC, GAC, MERCEDES-BENZ, DAIHATSU, Honda, Hyundai, Chevrolet, HAVAL, BENTLEY, GENESIS, JAGUAR, ROLLS ROYCE, Kia, Tesla, Ford, HERO, VOLVO, BAIC, Mitsubishi, CHRYSLER, SKODA, HONGQI, VICTORY, SUBARU, GREAT WALL, MASERATI, CHERY, BESTUNE, EXEED, MAXUS, TANK, Land Rover, Volkswagen, LAMBORGHINI, FIAT, HUMMER, Yamaha, Harley-Davidson, Suzuki, FERRARI, Dodge, ALFA ROMEO, Mazda, Bajaj, Infiniti, RABDAN, Jeep, DFSK, Audi, Kawasaki, OPEL, AVATR, ZEEKR, ABARTH, TVS, Vespa, Polaris, CHERY - ICAR, MERCURY, FORTHING, SOUEAST, HINO, SANYA, Mini, DEEPAL, Cadillac, VOYAH, CITROEN, ASTON MARTIN, Porsche, SHARMAX, KAIYI, ZNA, CMC, POLESTAR, Renault, XAOMI, ASHOK LEYLAND, BYD - DENZA, SMART, MCLAREN, I
# ...

# %%
import pandas as pd
import numpy as np

# ==========================================================
# MAKE / BRAND NORMALIZATION
# ==========================================================

MAKE_MAPPING = {

    # Toyota
    "TOYOTA2100875058": "TOYOTA",
    "TOYOTA": "TOYOTA",

    # Nissan
    "NISSAN": "NISSAN",
    "NISSEN": "NISSAN",

    # Mercedes
    "MERCEDES BENZ": "MERCEDES-BENZ",
    "MERCEDES": "MERCEDES-BENZ",
    "MERCEDES-BENZ": "MERCEDES-BENZ",

    # Chevrolet
    "CHERVOLET": "CHEVROLET",
    "CHEVROLET": "CHEVROLET",

    # Ford
    "FORD ": "FORD",
    "FORD": "FORD",

    # Hyundai
    "HYUNDAI2120117999": "HYUNDAI",
    "HYUNDAI": "HYUNDAI",

    # Kia
    "KIA ": "KIA",
    "KIA41964": "KIA",
    "KIA": "KIA",

    # Tesla
    "TESLA2130144264": "TESLA",
    "TESLA": "TESLA",

    # Land Rover
    "RANGE ROVER": "LAND ROVER",
    "RANGE  ROVER": "LAND ROVER",
    "LAND ROVER": "LAND ROVER",

    # Harley Davidson
    "HARLEY": "HARLEY-DAVIDSON",
    "HARLEY DAVIDSON": "HARLEY-DAVIDSON",
    "HARLEY-DAVIDSON": "HARLEY-DAVIDSON",

    # Yamaha
    "YAHAMA": "YAMAHA",
    "YAMAH": "YAMAHA",
    "YAMAHA": "YAMAHA",

    # Kawasaki
    "KAWAZAKI": "KAWASAKI",
    "KAWASAKI": "KAWASAKI",

    # Vespa
    "VESPA ": "VESPA",
    "VESPA": "VESPA",
    "VESPAA": "VESPA",

    # Polaris
    "POLARIS": "POLARIS",
    "POL": "POLARIS",
    "POLARIS ": "POLARIS",

    # Can-Am
    "CAN-AM": "CAN-AM",
    "CAN AM": "CAN-AM",
    "CAN -AM": "CAN-AM",
    "CAN": "CAN-AM",

    # Chery
    "CHERY - ICAR": "CHERY",
    "CHERY - ICAR": "CHERY",
    "CHERY - ICAR": "CHERY",
    "CHERY - ICAR": "CHERY",

    # Xiaomi
    "XAOMI": "XIAOMI",
    "XIAOMI": "XIAOMI",

    # Leapmotor
    "LEAPMOTORS": "LEAPMOTOR",
    "LEAPMOTOR": "LEAPMOTOR",

    # Li Auto
    "LI AUTO": "LI AUTO",
    "LI AUTO ": "LI AUTO",
    "LIXIANG": "LI AUTO",
    "LEADING IDEAL": "LI AUTO",
    "LEADING": "LI AUTO",

    # Great Wall
    "GWM - WEY": "GREAT WALL",
    "GREAT WALL": "GREAT WALL",

    # Dongfeng
    "DONGFENG EΠ": "DONGFENG",
    "DONGFENG EΠ": "DONGFENG",
    "DONGFENG-AEOLUS": "DONGFENG",
    "DONGFENG-XIAOKA": "DONGFENG",
    "DONGFENG": "DONGFENG",

    # Vanderhall
    "VANDER": "VANDERHALL",
    "VANDERHALL ": "VANDERHALL",
    "VANDERHALL": "VANDERHALL",

    # Sharmax
    "SHARAMAX": "SHARMAX",
    "SHARMAX ": "SHARMAX",
    "SHARMAX": "SHARMAX",

    # Sanya
    "SANIYA": "SANYA",
    "SANYA ": "SANYA",
    "SANYA": "SANYA",

    # BMW
    "BMWB": "BMW",
    "BMW": "BMW",

    # Bajaj
    "BAJA": "BAJAJ",
    "BAJAJ": "BAJAJ",

    # Mini
    "MINI COUPE": "MINI",
    "MINI": "MINI",

    # Hino
    "HINO": "HINO",

    # Mahindra
    "MAHINDRA ": "MAHINDRA",
    "MAHINDRA": "MAHINDRA",

    # Citroen
    "CITROEN": "CITROEN",

    # Opel
    "OPEL": "OPEL",

    # Smart
    "SMART": "SMART",

    # Buick
    "BUICK": "BUICK",

    # Victory
    "VICTORIA": "VICTORY",
    "VICTORY ": "VICTORY",
    "VICTORY": "VICTORY",
}

INVALID_MAKES = {
    "",
    " ",
    "-",
    "NAN",
    "UNKNOWN",
    "STD",
    "POWER",
    "TRD",
    "LX",
    "A",
    "CH",
    "HH",
    "HS",
    "HO",
    "AM",
    "MAC",
    "MOCK",
    "G10",
    "T7",
    "MV",
    "HIG",
    "PADAR",
    "DEXER",
    "SWIFT",
    "EQUATION",
    "TRALER",
}

def clean_make(
    data: pd.DataFrame,
    column: str = "make",
    rare_threshold: int = 5
):

    data = data.copy()

    data[column] = (
        data[column]
        .astype(str)
        .str.upper()
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
        .str.replace(r"\d+$", "", regex=True)  # remove trailing IDs
        .str.strip()
    )

    data[column] = data[column].replace(MAKE_MAPPING)

    data.loc[
        data[column].isin(INVALID_MAKES),
        column
    ] = np.nan

    counts = data[column].value_counts()

    rare_values = counts[counts < rare_threshold].index

    data.loc[
        data[column].isin(rare_values),
        column
    ] = "OTHER"

    return data


# ==========================================================
# APPLY
# ==========================================================

data = clean_make(
    data,
    column="make",
    rare_threshold=5
)

print(f"Unique Makes: {data['make'].nunique()}")
print(data["make"].value_counts(dropna=False).head(100))
# Out:
# Unique Makes: 171
# make
# TOYOTA         239215
# NISSAN         207966
# LEXUS           63911
# HONDA           52117
# MITSUBISHI      50222
#                 ...
# INEOS              83
# BYD - DENZA        82
# MCLAREN            78
# TATA               75
# FOTON              67
# Name: count, Length: 100, dtype: int64

# %%
print(", ".join(map(str, data['bodyType'].unique())))
# Out:
# SEDAN, Mini Bus High Roof, Pick Up Double Cab, SUV, HATCHBACK, Pick Up Single Cab, Panel Van, BUS, MPV, Estate, Pick Up, VAN, Mini Bus, COUPE, SUV- CROSSOVER, PICKUP, SALOON, Panel Van High Roof, Saloon, Station, Pickup, Hatchback, Sedan, MINI BUS, PICK UP SINGLE CAB, Half Panel Van, PICK UP DOUBLE CAB, CONVERTIBLE, PANEL VAN, Coupe, CARGO VAN, MINIVAN, Mini Bus Semi High Roof, Bus, PICK UP, Van, CARAVAN, PICKUP TRUCK, Light Vehicle, Motorcycle, Pickup Single Cabin, Truck, Pick Up Double Cabin, Pickup Double Cabin, COUPE/CABRIOLET, Ambulance, Regular Cab, Pickup Double Cab, Window Van, MINI BUS HIGH ROOF, MOTORCYCLE, Wagon, PICK-UP, PanelVan Wide Body High Roof, LIGHT VEHICLE, Refrigerator, Pick Up Double C, TRUCK, Van Cargo, Pick-Up with crane, Water Tank, Pick-Up, Sports Car, TANKER, Mini Bus LWB Wide Body HR, Diesel Tanker, sedan, coupe, SINGLE CABIN LONG CHASSIS, SINGLE CABIN LONG CARGO, Pick Up LWB, SINGLE CABIN STD CHASSIS, PICK UP DOUBLE CAB LONG BOX, PICK-UP WITH BOX, COACH, 
# ...

# %%
import pandas as pd
import numpy as np

BODY_TYPE_MAPPING = {

    # Sedan
    "SEDAN": "SEDAN",
    "SALOON": "SEDAN",
    "SALOON ": "SEDAN",
    "sedan".upper(): "SEDAN",

    # Hatchback
    "HATCHBACK": "HATCHBACK",

    # SUV
    "SUV": "SUV",
    "SUV- CROSSOVER": "SUV",
    "SUV- COMPACT": "SUV",
    "SUV COUPE": "SUV",
    "SUV CONVERTIBLE": "SUV",
    "CROSSOVER": "SUV",

    # Coupe
    "COUPE": "COUPE",
    "COUPE/CABRIOLET": "COUPE",
    "SPORTBACK": "COUPE",
    "SPORTS CAR": "COUPE",
    "TARGA": "COUPE",
    "coupe".upper(): "COUPE",

    # Convertible
    "CONVERTIBLE": "CONVERTIBLE",

    # Wagon
    "ESTATE": "WAGON",
    "STATION": "WAGON",
    "WAGON": "WAGON",

    # MPV
    "MPV": "MPV",
    "MINIVAN": "MPV",
    "MINI VAN": "MPV",
    "MINIVAN": "MPV",
    "CARAVAN": "MPV",

    # Van
    "VAN": "VAN",
    "VAN PASSENGER": "VAN",
    "WINDOW VAN": "VAN",
    "LONG VAN": "VAN",
    "SWB VAN": "VAN",
    "LWB VAN": "VAN",

    # Cargo Van
    "PANEL VAN": "CARGO VAN",
    "PANEL VAN HIGH ROOF": "CARGO VAN",
    "PANELVAN WIDE BODY HIGH ROOF": "CARGO VAN",
    "HALF PANEL VAN": "CARGO VAN",
    "CARGO VAN": "CARGO VAN",
    "VAN CARGO": "CARGO VAN",

    # Bus
    "BUS": "BUS",
    "MINI BUS": "BUS",
    "MINI BUS HIGH ROOF": "BUS",
    "MINI BUS SEMI HIGH ROOF": "BUS",
    "MINI BUS LWB": "BUS",
    "MINI BUS LWB WIDE BODY HR": "BUS",
    "COACH": "BUS",

    # Pickup
    "PICK UP": "PICKUP",
    "PICKUP": "PICKUP",
    "PICK-UP": "PICKUP",
    "PICK-UP WITH BOX": "PICKUP",
    "PICKUP WITH BOX": "PICKUP",
    "PICK-UP WITH CRANE": "PICKUP",
    "PICK UP CARGO": "PICKUP",
    "PICK UP DOUBLE": "PICKUP",

    "PICK UP SINGLE CAB": "PICKUP SINGLE CAB",
    "PICKUP SINGLE CABIN": "PICKUP SINGLE CAB",
    "SINGLE CABIN STD CHASSIS": "PICKUP SINGLE CAB",
    "SINGLE CABIN LONG CHASSIS": "PICKUP SINGLE CAB",
    "SINGLE CABIN LONG CARGO": "PICKUP SINGLE CAB",
    "REGULAR CAB": "PICKUP SINGLE CAB",

    "PICK UP DOUBLE CAB": "PICKUP DOUBLE CAB",
    "PICKUP DOUBLE CAB": "PICKUP DOUBLE CAB",
    "PICK UP DOUBLE CABIN": "PICKUP DOUBLE CAB",
    "PICKUP DOUBLE CABIN": "PICKUP DOUBLE CAB",
    "PICK UP DOUBLE CAB LONG BOX": "PICKUP DOUBLE CAB",
    "PICK UP DOUBLE C": "PICKUP DOUBLE CAB",

    "PICK UP EXT CAB": "PICKUP EXTENDED CAB",

    # Truck
    "TRUCK": "TRUCK",
    "HEAVY TRUCK": "TRUCK",
    "DUMP TRUCK": "TRUCK",
    "TRUCK WITH BOX": "TRUCK",
    "TRUCK WITH CRANE": "TRUCK",

    # Tanker
    "TANKER": "TANKER",
    "DIESEL TANKER": "TANKER",
    "WATER TANK": "TANKER",

    # Ambulance
    "AMBULANCE": "AMBULANCE",

    # Motorcycle
    "MOTORCYCLE": "MOTORCYCLE",

    # Heavy Equipment
    "HEAVY EQUIPMENT": "HEAVY EQUIPMENT",
    "FORKLIFT": "HEAVY EQUIPMENT",
    "FORK LIFT": "HEAVY EQUIPMENT",
    "EXCAVATOR": "HEAVY EQUIPMENT",
    "CRANE": "HEAVY EQUIPMENT",
    "LOCOMOTIVE": "HEAVY EQUIPMENT",

    # Hard Top
    "HARD TOP": "HARD TOP",

    # Jeep Wrangler special case
    "JEEP WRANGLER": "SUV",
}

INVALID_BODY_TYPES = {
    "",
    "NAN",
    "-",
    "MITSUBISHI",
    "MINI",
    "LIGHT VEHICLE",
    "REFRIGERATOR",
    "MOBILE WORKSHOP",
}

def clean_body_type(
    data: pd.DataFrame,
    column: str = "body_type",
    rare_threshold: int = 10
):

    data = data.copy()

    data[column] = (
        data[column]
        .astype(str)
        .str.upper()
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
    )

    data[column] = data[column].replace(BODY_TYPE_MAPPING)

    data.loc[
        data[column].isin(INVALID_BODY_TYPES),
        column
    ] = np.nan

    counts = data[column].value_counts()

    rare_values = counts[counts < rare_threshold].index

    data.loc[
        data[column].isin(rare_values),
        column
    ] = "OTHER"

    return data


# APPLY
data = clean_body_type(
    data,
    column="bodyType",
    rare_threshold=10
)

print(f"Unique Body Types: {data['bodyType'].nunique()}")
print(data["bodyType"].value_counts(dropna=False))
# Out:
# Unique Body Types: 22
# bodyType
# SEDAN                  411023
# SUV                    359489
# HATCHBACK               66015
# PICKUP DOUBLE CAB       26918
# PICKUP                  24447
# MPV                     20836
# COUPE                   17684
# MOTORCYCLE              16639
# PICKUP SINGLE CAB       16140
# BUS                     11374
# CARGO VAN                9932
# CONVERTIBLE              3022
# VAN                      2190
# WAGON                    1646
# PICKUP EXTENDED CAB      1291
# PICKUP TRUCK              592
# TRUCK                     230
# TANKER                     75
# NaN                        45
# PICK UP LWB                33
# HARD TOP                   28
# HEAVY EQUIPMENT            15
# OTHER                       5
# Name: count, dtype: int64

# %%
print(", ".join(map(str, data['trim'].unique())))
# Out:
# SE, GLX, DX, DL, XLI, VX, MID, DLX, VXR, FABRIC, E, TOP, EXTREME, GL, BASE, S, FLEET, STD (NON GCC), GXR, EXR, SE+ ANNIVERSARY EDITION, GL2, SR5, STD, LE, XLI MID, LE (NON GCC), SE+, GLI, SR5 (NON GCC), TX, LIMITED, XLE (NON GCC), SE TRD AERO PK, EX, ICONIC, VX MID, LE HEV, SGLX, PW CL, GX, XLE, SPORT, G, GRANDE, GR, XLI TOP, S TRD SPORT PK, S+, PRO, XLI RB, LIMITED PREMIUM, GLE, XLI EXECUTIVE, GLS, PLATINUM, DLX TOP, TURBO G RA, LIMITED (NON GCC), SR5 4X4, VXR HEV, GLE HEV, SAFARI, LX, GXR TOP 60th ANNIV. XTREME, CE (NON GCC), GLI HEV, PREMIUM, XLI EXECUTIVE MR, XL, GXR TOP, VXR BASE, LX AC PWR OPT, LX WINCH, TX-L, XLE TOURING, GXR GT, DLS, VXR TOP, SC, GLE-X HEV 40TH ANNIV, SALOON, nan, ADVENTURE, CREWMAX CAPSTONE (NON GCC), LE STD, LIMITED MID, GX TOP, TX-L TOP, GLI TOP, EXCLUSIVE, XSE (NON GCC), BLACK EDITION, DX H/R W/B, C (NON GCC), XLI POWER OPT, GLX SPORT Z, S PLUS, VTX, GXL, HT SWB, GXR MID, ECO, GX MID, GXR2, LWB HIGH ROOF, 1794 EDITION (NON GCC), 40TH ANNIVERSARY EDITION, 
# ...

# %%
import pandas as pd
import numpy as np


def clean_trim(data: pd.DataFrame,
               column: str = "trim") -> pd.DataFrame:

    data = data.copy()

    # =====================================================
    # STANDARDIZE
    # =====================================================

    data[column] = (
        data[column]
        .astype(str)
        .str.upper()
        .str.strip()
        .str.replace(r"\s*\(NON GCC\)", "", regex=True)
        .str.replace(r"\s*\( NON GCC \)", "", regex=True)
        .str.replace("NON GCC", "", regex=False)
        .str.replace("NON-GCC", "", regex=False)
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
    )

    # =====================================================
    # TRIM NORMALIZATION
    # =====================================================

    TRIM_MAPPING = {

        # =========================
        # GLX
        # =========================
        "SGLX": "GLX",
        "GLX SPORT Z": "GLX",
        "GLX TOP": "GLX",
        "GLX PREMIUM": "GLX",
        "GLX HIGHLINE": "GLX",

        # =========================
        # GLI
        # =========================
        "GLI TOP": "GLI",
        "GLI HEV": "GLI",
        "HEV GLI": "GLI",
        "GLI TOP LTH": "GLI",
        "GLI TOP LEATHER": "GLI",
        "GLI MR HEV": "GLI",
        "GLI-2.0 LAUTOMATIC": "GLI",

        # =========================
        # XLI
        # =========================
        "XLI MID": "XLI",
        "XLI TOP": "XLI",
        "XLI RB": "XLI",
        "XLI EXECUTIVE": "XLI",
        "XLI EXECUTIVE MR": "XLI",
        "XLI EXECUTIVE HEV": "XLI",
        "XLI POWER OPT": "XLI",
        "XLI+": "XLI",
        "XLI - AW": "XLI",
        "XLI 1.8": "XLI",
        "XLI 1.8L": "XLI",
        "XLI HEV": "XLI",

        # =========================
        # GX
        # =========================
        "GX MID": "GX",
        "GX TOP": "GX",

        # =========================
        # GXR
        # =========================
        "GXR1": "GXR",
        "GXR2": "GXR",
        "GXR3": "GXR",
        "GXR4": "GXR",
        "GXR MID": "GXR",
        "GXR TOP": "GXR",
        "GXR GT": "GXR",
        "GXR FMST": "GXR",
        "GXR TOP FMST": "GXR",
        "GXR TOP DMST": "GXR",
        "GXR SOD D/AC AW": "GXR",
        "GXR+": "GXR",
        "GXR-V": "GXR",
        "GXR HEV": "GXR",
        "GXR MID XTREME": "GXR",
        "GXR MID 60TH ANNIVERSARY": "GXR",
        "GXR MID 60TH ANNIV. XTREME": "GXR",
        "GXR TOP 60TH ANNIV.": "GXR",
        "GXR TOP 60TH ANNIV. XTREME": "GXR",

        # =========================
        # VXR
        # =========================
        "VXR BASE": "VXR",
        "VXR MID": "VXR",
        "VXR TOP": "VXR",
        "VXR TOP LTH": "VXR",
        "VXR HEV": "VXR",
        "HT VXR": "VXR",

        # =========================
        # VX
        # =========================
        "VX MID": "VX",
        "VX TOP LTH": "VX",
        "VX1": "VX",
        "VX2": "VX",
        "VX2 PLUS": "VX",
        "VX-L MID": "VX",
        "VX-L TOP": "VX",

        # =========================
        # TX
        # =========================
        "TX-L": "TX",
        "TXL1": "TX",
        "TXL2": "TX",
        "TXL3": "TX",
        "TX-L TOP": "TX",
        "TXR": "TX",

        # =========================
        # LE
        # =========================
        "LE HEV": "LE",
        "LE STD": "LE",
        "LE TITANIUM": "LE",
        "LE PLATINUM CITY": "LE",

        # =========================
        # SE
        # =========================
        "SE+": "SE",
        "SE T1": "SE",
        "SE T2": "SE",
        "SE TITANIUM": "SE",
        "SE TRD SPORT PK": "SE",
        "SE TRD AERO PK": "SE",
        "SE+ ANNIVERSARY EDITION": "SE",
        "SE+ ANNIVERSARY EDIT": "SE",

        # =========================
        # S
        # =========================
        "S+": "S",
        "S PLUS": "S",
        "S ASF": "S",
        "S T1": "S",
        "S T2 TOP": "S",
        "S TRD SPORT PK": "S",
        "S TRD AERO PK": "S",

        # =========================
        # GLE
        # =========================
        "GLE HEV": "GLE",
        "GLE-X": "GLE",
        "GLE-X HEV": "GLE",

        # =========================
        # LIMITED
        # =========================
        "LIMITED PREMIUM": "LIMITED",
        "LIMITED HEV": "LIMITED",
        "LIMITED TOP": "LIMITED",
        "LIMITED MID": "LIMITED",
        "LIMITED 4X4": "LIMITED",
        "LIMITED 4X2": "LIMITED",
        "LIMITED TRD SPORT PK": "LIMITED",
        "LIMITED TRD AERO PK": "LIMITED",

        # =========================
        # PLATINUM
        # =========================
        "PLATINUM LUXURY 4X4": "PLATINUM",

        # =========================
        # PREMIUM
        # =========================
        "PREMIUM PLUS": "PREMIUM",

        # =========================
        # GRANDE
        # =========================
        "GRANDE HEV": "GRANDE",
        "GRANDE LTH": "GRANDE",
        "GRANDE HEV 40TH ANNIV": "GRANDE",

        # =========================
        # GR
        # =========================
        "GR SPORT": "GR",
        "GR-S": "GR",
        "GR BLUE EDITION": "GR",
        "GR TAN EDITION": "GR",

        # =========================
        # ADVENTURE
        # =========================
        "ADVENTURE 1ST EDITION": "ADVENTURE",
        "ADVENTURE 1ST EDITIO": "ADVENTURE",

        # =========================
        # ANNIVERSARY
        # =========================
        "40TH ANNIVERSARY EDITION": "ANNIVERSARY EDITION",
        "40TH ANNIVERSARY EDI": "ANNIVERSARY EDITION",
        "LUMIERE 40TH ANNIV": "ANNIVERSARY EDITION",
        "60TH": "ANNIVERSARY EDITION",

        # =========================
        # STD
        # =========================
        "STDD": "STD",
        "STAND": "STD",
        "STAN": "STD",
        "STANDAR": "STD",
        "STANDER": "STD",
        "STANDERD": "STD",
        "STANDARD": "STD",
        "STD AC": "STD",
        "STD D": "STD",
        "STD CARGO": "STD",
    }

    data[column] = data[column].replace(TRIM_MAPPING)

    # =====================================================
    # REMOVE PURE GARBAGE VALUES
    # =====================================================

    INVALID_TRIMS = {
        "",
        " ",
        "NAN",
        "-",
        "00",
        "000",
        "0000",
        "00000",
        "0",
        "1",
        "2",
        "4",
        "5",
        "6",
        "45",
        "90",
        "100",
        "1000",
        "1500",
        "2400",
        "LMV",
        "CAR TRIM",
        "TRIM",
        "TERIM",
        "TRTIM",
        "NA",
    }

    data.loc[
        data[column].isin(INVALID_TRIMS),
        column
    ] = np.nan

    return data


# =====================================================
# APPLY
# =====================================================

data = clean_trim(data, column="trim")

print(f"Unique trims: {data['trim'].nunique()}")
print(data["trim"].value_counts(dropna=False).head(200))
# Out:
# Unique trims: 2640
# trim
# STD                        107895
# S                           71789
# SE                          46283
# GL                          41029
# SV                          40166
#                             ...
# STYLE                         404
# PURE                          401
# P75 STANDARD RANGE PLUS       401
# DELUXE                        401
# GLX MID LINE                  397
# Name: count, Length: 200, dtype: int64

# %%
data
# Out:
#              chassisNumber    year      make    model trim           bodyType  \
# 0        RKLBB9HE7F5115863  2015.0    TOYOTA  COROLLA   SE              SEDAN
# 1        JTFHX02POF0099797  2015.0    TOYOTA    HIACE  GLX                BUS
# 2        JTFHX02P7F0094323  2015.0    TOYOTA    HIACE   DX                BUS
# 3        JTFHXDGP7F0094373  2015.0    TOYOTA    HILUX   DL  PICKUP DOUBLE CAB
# 4        4T1BG22K01U789089  2001.0    TOYOTA    CAMRY  XLI              SEDAN
# ...                    ...     ...       ...      ...  ...                ...
# 1009598  HY2PEAND0PB000238  2023.0     OTHER    OTHER  NaN         MOTORCYCLE
# 1009599  LNGPCMXJ9PL305272  2023.0     OTHER    OTHER  NaN         MOTORCYCLE
# 1009600  LURJAVBM8PA024843  2023.0     OTHER    OTHER  STD              COUPE
# 1009601  7KGTC2C48NR003646  2022.0     OTHER    OTHER  NaN         MOTORCYCLE
# 1009602  LX6TK334XS2510023  2025.0  CHANGHUA    OTHER  NaN         MOTORCYCLE
#
# ...

# %%
def clean_make(
    data: pd.DataFrame,
    column: str = "make"
):

    data = data.copy()

    data[column] = (
        data[column]
        .astype(str)
        .str.upper()
        .str.strip()
        .str.replace(r"\s+", " ", regex=True)
        .str.replace(r"\d+$", " ",)
# Out:
#   Cell In[24], line 14
#     .str.replace(r"\d+$", "")
#                              ^
# _IncompleteInputError: incomplete input
