# %%
import pandas as pd

# %%
data = pd.read_csv("../Data/df_.csv")
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14568\3550776980.py:1: DtypeWarning: Columns (6,25,26,44,64,65,67,68,69) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../Data/df_.csv")
#                                          _id      make       model  \
# 0       {'$oid': '68592fc0f32ddc587c27aafb'}    TOYOTA       HIACE
# 1       {'$oid': '685935005d8bb5f0ab18a181'}    TOYOTA       HIACE
# 2       {'$oid': '685944995d8bb5f0ab18bafc'}    TOYOTA       HILUX
# 3       {'$oid': '68596237e6bdae3db611dab9'}  INFINITI        QX50
# 4       {'$oid': '685bb1456ce98addfc08ed19'}       BMW        420I
# ...                                      ...       ...         ...
# 545766  {'$oid': '695b4f43bdc8aedbe0f991eb'}     HONDA      ACCORD
# 545767  {'$oid': '695b4f437788260f978b08b8'}    TOYOTA     COROLLA
# 545768  {'$oid': '695b4f4f895b880bf8233793'}    JETOUR          T2
# 545769  {'$oid': '695b4f51895b880bf8233850'}   PEUGEOT        3008
# ...

# %%
data = data[["chassisNumber", "make", "model", "trim", "bodyType", "cylinders", "year", "origin","weightInKg", "color", "noOfPassengers", "price"]]

# %%
data
# Out:
#             chassisNumber      make       model             trim  \
# 0       JTFHX02P7F0094323    TOYOTA       HIACE               DX
# 1       JTFHX02P7F0094323    TOYOTA       HIACE               DX
# 2       JTFHXDGP7F0094373    TOYOTA       HILUX               DL
# 3       JN1ASNYC3PU200564  INFINITI        QX50       LUXE STYLE
# 4       WBA11AP04RCR41747       BMW        420I  M SPORT PREMIUM
# ...                   ...       ...         ...              ...
# 545766  LUCCR2626F3412739     HONDA      ACCORD               LX
# 545767  JTDBR22E770294249    TOYOTA     COROLLA              XLI
# 545768  HEVPBECB2RB421697    JETOUR          T2              LUX
# 545769  VF3M45GY4LS010883   PEUGEOT        3008           ACTIVE
# 545770  JTEBU11F7MK259693    TOYOTA  FJ CRUISER              GXR
#
#                   bodyType  cylinders  year   origin  weightInKg  \
# 0       Mini Bus High Roof        4.0  2015    Japan      1837.0
# ...

# %%
for col in data.columns:
    if data[col].dtype == "object":
        data[col] = [x.upper() if isinstance(x, str) else x for x in data[col]]

print(data.head())
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_14568\3846488023.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col] = [x.upper() if isinstance(x, str) else x for x in data[col]]
#        chassisNumber      make  model             trim            bodyType  \
# 0  JTFHX02P7F0094323    TOYOTA  HIACE               DX  MINI BUS HIGH ROOF
# 1  JTFHX02P7F0094323    TOYOTA  HIACE               DX  MINI BUS HIGH ROOF
# 2  JTFHXDGP7F0094373    TOYOTA  HILUX               DL  PICK UP DOUBLE CAB
# 3  JN1ASNYC3PU200564  INFINITI   QX50       LUXE STYLE                 SUV
# 4  WBA11AP04RCR41747       BMW   420I  M SPORT PREMIUM               COUPE
#
#    cylinders  year   origin  weightInKg  color  noOfPassengers     price
# ...

# %%
data
# Out:
#             chassisNumber      make       model             trim  \
# 0       JTFHX02P7F0094323    TOYOTA       HIACE               DX
# 1       JTFHX02P7F0094323    TOYOTA       HIACE               DX
# 2       JTFHXDGP7F0094373    TOYOTA       HILUX               DL
# 3       JN1ASNYC3PU200564  INFINITI        QX50       LUXE STYLE
# 4       WBA11AP04RCR41747       BMW        420I  M SPORT PREMIUM
# ...                   ...       ...         ...              ...
# 545766  LUCCR2626F3412739     HONDA      ACCORD               LX
# 545767  JTDBR22E770294249    TOYOTA     COROLLA              XLI
# 545768  HEVPBECB2RB421697    JETOUR          T2              LUX
# 545769  VF3M45GY4LS010883   PEUGEOT        3008           ACTIVE
# 545770  JTEBU11F7MK259693    TOYOTA  FJ CRUISER              GXR
#
#                   bodyType  cylinders  year   origin  weightInKg  \
# 0       MINI BUS HIGH ROOF        4.0  2015    JAPAN      1837.0
# ...

# %%
data = data.loc[data['make'].map(data['make'].value_counts()).sort_values(ascending=False).index]

# %%
data.drop_duplicates(subset=['chassisNumber'], keep='first', inplace=True)

# %%
data["chassis_len"] = data["chassisNumber"].str.len()

is_standard = (data["chassis_len"] == 17) 
data = data[is_standard]
data
# Out:
#             chassisNumber               make          model          trim  \
# 545751  MR0FX22G091017515             TOYOTA          HILUX           DLX
# 545745  JTEGD52M48A004201             TOYOTA         PREVIA            GL
# 545744  JTMAUBBJ2S4107332             TOYOTA   LAND CRUISER          GXR2
# 30      5TDZK23C87S071537             TOYOTA         SIENNA  LE (NON GCC)
# 29      JTEBU11F39K063774             TOYOTA     FJ CRUISER          BASE
# ...                   ...                ...            ...           ...
# 452581  MALC741C6JM063605  HYUNDAI2120117999         ACCENT            GL
# 267973  LZBTX9C73P1000180                NaN         FX 200           NaN
# 316780  LRW3E7ES9RC964797                NaN            NaN           NaN
# 364898  METM85002S3003418                NaN  VESPA VXL 150           NaN
# 421129  57XAARFA3H8121499                NaN     SLING SHOT           NaN
#
#                   bodyType  cylinders  year    origin  weightInKg  \
# ...

# %%
data.head()
# Out:
#             chassisNumber    make         model          trim  \
# 545751  MR0FX22G091017515  TOYOTA         HILUX           DLX
# 545745  JTEGD52M48A004201  TOYOTA        PREVIA            GL
# 545744  JTMAUBBJ2S4107332  TOYOTA  LAND CRUISER          GXR2
# 30      5TDZK23C87S071537  TOYOTA        SIENNA  LE (NON GCC)
# 29      JTEBU11F39K063774  TOYOTA    FJ CRUISER          BASE
#
#                   bodyType  cylinders  year    origin  weightInKg  color  \
# 545751  PICK UP DOUBLE CAB        4.0  2009  THAILAND      1600.0  WHITE
# 545745                 MPV        6.0  2008     JAPAN      1000.0  WHITE
# 545744                 SUV        6.0  2025     JAPAN         NaN  WHITE
# 30                     MPV        6.0  2007   AMERICA      1600.0  WHITE
# 29                     SUV        6.0  2009     JAPAN      2000.0   GREY
#
#         noOfPassengers     price  chassis_len
# 545751             5.0   21000.0         17.0
# 545745             7.0   14000.0         17.0
# ...

# %%
data.to_csv("../Data/df__.csv", index=False)

# %%
data = data.loc[data['model'].map(data['model'].value_counts()).sort_values(ascending=False).index]

# %%
data
# Out:
#             chassisNumber    make  model                     trim    bodyType  \
# 104     4T1BF1FK2GU959033  TOYOTA  CAMRY                       SE       SEDAN
# 545617  6T1BF4FK1FX532784  TOYOTA  CAMRY                  LIMITED       SEDAN
# 65      JTNBZ4HK6R3035774  TOYOTA  CAMRY  SE+ ANNIVERSARY EDITION       SEDAN
# 545644  4T1BE46K77U562096  TOYOTA  CAMRY                      GLI       SEDAN
# 545646  JTNB14HKOP3183813  TOYOTA  CAMRY                       SE       SEDAN
# ...                   ...     ...    ...                      ...         ...
# 93935   JN100KY60Z0860741  NISSAN    NaN                        0         SUV
# 157181  1HFSC47A37A600818   HONDA    NaN                      NaN  MOTORCYCLE
# 261594  ME4KC401CLA014664   HONDA    NaN                      NaN  MOTORCYCLE
# 537043  ME4KC40A4TA005771   HONDA    NaN                      NaN  MOTORCYCLE
# 316780  LRW3E7ES9RC964797     NaN    NaN                      NaN       SEDAN
#
# ...
