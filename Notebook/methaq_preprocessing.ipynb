# %%
import numpy as np

# %%
import pandas as pd

# %%
df1 = pd.read_json("../chunks/chunk_1.json")

# %%
df2 = pd.read_json("../chunks/chunk_2.json")
df3 = pd.read_json("../chunks/chunk_3.json")
df4 = pd.read_json("../chunks/chunk_4.json")
df5 = pd.read_json("../chunks/chunk_5.json")
df6 = pd.read_json("../chunks/chunk_6.json")
df7 = pd.read_json("../chunks/chunk_7.json")
df8 = pd.read_json("../chunks/chunk_8.json")
df9 = pd.read_json("../chunks/chunk_9.json")
df10 = pd.read_json("../chunks/chunk_10.json")

# %%
df1
# Out:
#                                          _id      make         model  \
# 0       {'$oid': '68592fc0f32ddc587c27aafb'}    TOYOTA         HIACE
# 1       {'$oid': '685935005d8bb5f0ab18a181'}    TOYOTA         HIACE
# 2       {'$oid': '685944995d8bb5f0ab18bafc'}    TOYOTA         HILUX
# 3       {'$oid': '68596237e6bdae3db611dab9'}  INFINITI          QX50
# 4       {'$oid': '685bb1456ce98addfc08ed19'}       BMW          420I
# ...                                      ...       ...           ...
# 167495  {'$oid': '6909af719d8fc5c1c4223f8d'}    NISSAN         URVAN
# 167496  {'$oid': '6909af719d8fc5c1c4223fd3'}    TOYOTA          RAV4
# 167497  {'$oid': '6909af72313f806a5690565e'}    NISSAN        ALTIMA
# 167498  {'$oid': '6909af73c1f64147c4d8d744'}    TOYOTA  LAND CRUISER
# 167499  {'$oid': '6909af79c1f64147c4d8d7f4'}    NISSAN        ALTIMA
#
#                    trim            bodyType cylinders  year     insureType  \
# 0                    DX  Mini Bus High Roof         4  2015     thirdparty
# 1                    DX  Mini Bus High Roof         4  2015     thirdparty
# 2                    DL  Pick Up Double Cab         4  2015  comprehensive
# 3            LUXE STYLE                 SUV         4  2024     thirdparty
# 4       M SPORT PREMIUM               COUPE         4  2024     thirdparty
# ...                 ...                 ...       ...   ...            ...
# 167495              STD            Mini Bus         4  2007     thirdparty
# 167496             BASE                 SUV         4  2010     thirdparty
# 167497               SL               SEDAN         4  2019     thirdparty
# 167498              VXR                 SUV         6  2021     thirdparty
# 167499               SV               SEDAN         4  2019     thirdparty
#
#             chassisNumber   price  ... transmission autoDataPrice  \
# 0       JTFHX02P7F0094323   48400  ...          NaN           NaN
# 1       JTFHX02P7F0094323   48400  ...          NaN           NaN
# 2       JTFHXDGP7F0094373   37800  ...          NaN           NaN
# 3       JN1ASNYC3PU200564  142000  ...          NaN           NaN
# 4       WBA11AP04RCR41747  156500  ...          NaN           NaN
# ...                   ...     ...  ...          ...           ...
# 167495  JN6FE54SX7X438060    7700  ...          NaN        7700.0
# 167496  2T3BF4DVXAW069893   17000  ...          NaN       17000.0
# 167497  1N4BL4EVXKC170000   55500  ...          NaN       55500.0
# 167498  JTMHY05J8M4095953  211200  ...          NaN      211200.0
# 167499  1N4BL4A98KC161692   53200  ...          NaN       53200.0
#
#        engineCapacity maxValue minValue mortgageBankName  \
# 0                 NaN      NaN      NaN              NaN
# 1                 NaN      NaN      NaN              NaN
# 2                 NaN      NaN      NaN              NaN
# 3                 NaN      NaN      NaN              NaN
# 4                 NaN      NaN      NaN              NaN
# ...               ...      ...      ...              ...
# 167495           None      0.0      0.0              NaN
# 167496           None      0.0      0.0              NaN
# 167497           None      0.0      0.0              NaN
# 167498           None      0.0      0.0              NaN
# 167499           None      0.0      0.0              NaN
#
#                        regCardNameAr applicantId userId carImages
# 0                                NaN         NaN    NaN       NaN
# 1                                NaN         NaN    NaN       NaN
# 2                                NaN         NaN    NaN       NaN
# 3                                NaN         NaN    NaN       NaN
# 4                                NaN         NaN    NaN       NaN
# ...                              ...         ...    ...       ...
# 167495   محطة ماجستي لخدمات السيارات         NaN    NaN        []
# 167496        نیتو بلا راجیندر کومار         NaN    NaN        []
# 167497          يعقوب خالد خليل عياد         NaN    NaN        []
# 167498  مسفر محمد عايض حنيف الاحبابي         NaN    NaN        []
# 167499   محمد راشد محمد راشد الحساني         NaN    NaN        []
#
# [167500 rows x 67 columns]

# %%
df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index=True)

# %%
df
# Out:
#                                           _id      make   model  \
# 0        {'$oid': '68592fc0f32ddc587c27aafb'}    TOYOTA   HIACE
# 1        {'$oid': '685935005d8bb5f0ab18a181'}    TOYOTA   HIACE
# 2        {'$oid': '685944995d8bb5f0ab18bafc'}    TOYOTA   HILUX
# 3        {'$oid': '68596237e6bdae3db611dab9'}  INFINITI    QX50
# 4        {'$oid': '685bb1456ce98addfc08ed19'}       BMW    420I
# ...                                       ...       ...     ...
# 1674107  {'$oid': '6a193215019e32974c5e3521'}    TOYOTA   HILUX
# 1674108  {'$oid': '6a19321b019e32974c5e355d'}        MG      GT
# 1674109  {'$oid': '6a19324e7ecc40bc38f32d6a'}   HYUNDAI  TUCSON
# 1674110  {'$oid': '6a1932558c9b2a52642e77d1'}  FORTHING  T5 EVO
# 1674111  {'$oid': '6a193265019e32974c5e35d2'}    NISSAN  PATROL
#
#                     trim            bodyType cylinders    year     insureType  \
# 0                     DX  Mini Bus High Roof         4    2015     thirdparty
# 1                     DX  Mini Bus High Roof         4    2015     thirdparty
# 2                     DL  Pick Up Double Cab         4    2015  comprehensive
# 3             LUXE STYLE                 SUV         4    2024     thirdparty
# 4        M SPORT PREMIUM               COUPE         4    2024     thirdparty
# ...                  ...                 ...       ...     ...            ...
# 1674107             SGLX  Pick Up Double Cab         4  2024.0  comprehensive
# 1674108           LUXURY               SEDAN         4  2022.0  comprehensive
# 1674109               GL                 SUV         4  2020.0  comprehensive
# 1674110        EXCLUSIVE                 SUV         4  2024.0  comprehensive
# 1674111  SUPER SAFARI HT                 SUV         6  2020.0  comprehensive
#
#              chassisNumber     price  ... carImages tradeLicenseName  \
# 0        JTFHX02P7F0094323     48400  ...       NaN              NaN
# 1        JTFHX02P7F0094323     48400  ...       NaN              NaN
# 2        JTFHXDGP7F0094373     37800  ...       NaN              NaN
# 3        JN1ASNYC3PU200564    142000  ...       NaN              NaN
# 4        WBA11AP04RCR41747    156500  ...       NaN              NaN
# ...                    ...       ...  ...       ...              ...
# 1674107               None   86400.0  ...        []              NaN
# 1674108               None   37810.0  ...        []              NaN
# 1674109               None   38880.0  ...        []              NaN
# 1674110  LMXA14AFXRZ354445   64644.0  ...        []              NaN
# 1674111               None  139175.0  ...        []              NaN
#
#                                           autoDataResponse  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1674107  {'vinDecoding': {'admeid': 34857, 'description...
# 1674108                                               None
# 1674109  {'vinDecoding': {'admeid': 25968, 'description...
# 1674110  {'make': 'FORTHING', 'model': 'T5 EVO', 'year'...
# 1674111  {'vinDecoding': {'admeid': 25961, 'description...
#
#         mortgageDocumentDate bodyTypeCode vehicleMileage ocrRCVerified  \
# 0                        NaN          NaN            NaN           NaN
# 1                        NaN          NaN            NaN           NaN
# 2                        NaN          NaN            NaN           NaN
# 3                        NaN          NaN            NaN           NaN
# 4                        NaN          NaN            NaN           NaN
# ...                      ...          ...            ...           ...
# 1674107                  NaN          NaN            1.0         False
# 1674108                  NaN          NaN            1.0         False
# 1674109                  NaN          NaN            1.0         False
# 1674110                  NaN          NaN            NaN         False
# 1674111                  NaN          NaN            1.0         False
#
#         ocrVCCVerified ocrNCCVerified ocrPassingPaperVerified
# 0                  NaN            NaN                     NaN
# 1                  NaN            NaN                     NaN
# 2                  NaN            NaN                     NaN
# 3                  NaN            NaN                     NaN
# 4                  NaN            NaN                     NaN
# ...                ...            ...                     ...
# 1674107          False          False                   False
# 1674108          False          False                   False
# 1674109          False          False                   False
# 1674110          False          False                   False
# 1674111          False          False                   False
#
# [1674112 rows x 76 columns]

# %%
df.isnull().sum()
# Out:
# _id                              0
# make                            23
# model                            6
# trim                         27134
# bodyType                         3
#                             ...
# vehicleMileage             1508498
# ocrRCVerified              1049262
# ocrVCCVerified             1049262
# ocrNCCVerified             1049262
# ocrPassingPaperVerified    1049262
# Length: 76, dtype: int64

# %%
df = df.astype(str)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_main = df[["chassisNumber", "make", "model", "trim", "bodyType", "cylinders", "year", "origin"]]

# %%
df_main
# Out:
#              chassisNumber      make   model             trim  \
# 0        JTFHX02P7F0094323    TOYOTA   HIACE               DX
# 1        JTFHX02P7F0094323    TOYOTA   HIACE               DX
# 2        JTFHXDGP7F0094373    TOYOTA   HILUX               DL
# 3        JN1ASNYC3PU200564  INFINITI    QX50       LUXE STYLE
# 4        WBA11AP04RCR41747       BMW    420I  M SPORT PREMIUM
# ...                    ...       ...     ...              ...
# 1674107               None    TOYOTA   HILUX             SGLX
# 1674108               None        MG      GT           LUXURY
# 1674109               None   HYUNDAI  TUCSON               GL
# 1674110  LMXA14AFXRZ354445  FORTHING  T5 EVO        EXCLUSIVE
# 1674111               None    NISSAN  PATROL  SUPER SAFARI HT
#
#                    bodyType cylinders    year   origin
# 0        Mini Bus High Roof         4    2015    Japan
# 1        Mini Bus High Roof         4    2015    Japan
# 2        Pick Up Double Cab         4    2015    Japan
# 3                       SUV         4    2024   Mexico
# 4                     COUPE         4    2024  Germany
# ...                     ...       ...     ...      ...
# 1674107  Pick Up Double Cab         4  2024.0    Japan
# 1674108               SEDAN         4  2022.0    China
# 1674109                 SUV         4  2020.0    Korea
# 1674110                 SUV         4  2024.0    CHINA
# 1674111                 SUV         6  2020.0    Japan
#
# [1674112 rows x 8 columns]

# %%
df_main.isnull().sum()
# Out:
# chassisNumber    0
# make             0
# model            0
# trim             0
# bodyType         0
# cylinders        0
# year             0
# origin           0
# dtype: int64

# %%
df_main[(df_main["chassisNumber"] == "None") | (df_main["chassisNumber"] == np.nan)]
# Out:
#         chassisNumber        make         model             trim  \
# 66               None         KIA        MOHAVE               EX
# 75               None         GMC        SIERRA             2500
# 3824             None      TOYOTA         CAMRY                E
# 4363             None    CADILLAC      ESCALADE         PLATINUM
# 4450             None      TOYOTA         HILUX              DLX
# ...               ...         ...           ...              ...
# 1674103          None  MITSUBISHI  PAJERO SPORT          LOWLINE
# 1674107          None      TOYOTA         HILUX             SGLX
# 1674108          None          MG            GT           LUXURY
# 1674109          None     HYUNDAI        TUCSON               GL
# 1674111          None      NISSAN        PATROL  SUPER SAFARI HT
#
#                    bodyType cylinders    year  origin
# 66                      SUV         6    2014
# 75       Pick Up Double Cab         8    2014  Mexico
# 3824                  SEDAN         4    2025
# 4363                    SUV         8    2018
# 4450     Pick Up Double Cab         4    2004
# ...                     ...       ...     ...     ...
# 1674103                 SUV         6  2011.0   Japan
# 1674107  Pick Up Double Cab         4  2024.0   Japan
# 1674108               SEDAN         4  2022.0   China
# 1674109                 SUV         4  2020.0   Korea
# 1674111                 SUV         6  2020.0   Japan
#
# [102073 rows x 8 columns]

# %%
df
# Out:
#                                           _id      make   model  \
# 0        {'$oid': '68592fc0f32ddc587c27aafb'}    TOYOTA   HIACE
# 1        {'$oid': '685935005d8bb5f0ab18a181'}    TOYOTA   HIACE
# 2        {'$oid': '685944995d8bb5f0ab18bafc'}    TOYOTA   HILUX
# 3        {'$oid': '68596237e6bdae3db611dab9'}  INFINITI    QX50
# 4        {'$oid': '685bb1456ce98addfc08ed19'}       BMW    420I
# ...                                       ...       ...     ...
# 1674107  {'$oid': '6a193215019e32974c5e3521'}    TOYOTA   HILUX
# 1674108  {'$oid': '6a19321b019e32974c5e355d'}        MG      GT
# 1674109  {'$oid': '6a19324e7ecc40bc38f32d6a'}   HYUNDAI  TUCSON
# 1674110  {'$oid': '6a1932558c9b2a52642e77d1'}  FORTHING  T5 EVO
# 1674111  {'$oid': '6a193265019e32974c5e35d2'}    NISSAN  PATROL
#
#                     trim            bodyType cylinders    year     insureType  \
# 0                     DX  Mini Bus High Roof         4    2015     thirdparty
# 1                     DX  Mini Bus High Roof         4    2015     thirdparty
# 2                     DL  Pick Up Double Cab         4    2015  comprehensive
# 3             LUXE STYLE                 SUV         4    2024     thirdparty
# 4        M SPORT PREMIUM               COUPE         4    2024     thirdparty
# ...                  ...                 ...       ...     ...            ...
# 1674107             SGLX  Pick Up Double Cab         4  2024.0  comprehensive
# 1674108           LUXURY               SEDAN         4  2022.0  comprehensive
# 1674109               GL                 SUV         4  2020.0  comprehensive
# 1674110        EXCLUSIVE                 SUV         4  2024.0  comprehensive
# 1674111  SUPER SAFARI HT                 SUV         6  2020.0  comprehensive
#
#              chassisNumber     price  ... carImages tradeLicenseName  \
# 0        JTFHX02P7F0094323     48400  ...       nan              nan
# 1        JTFHX02P7F0094323     48400  ...       nan              nan
# 2        JTFHXDGP7F0094373     37800  ...       nan              nan
# 3        JN1ASNYC3PU200564    142000  ...       nan              nan
# 4        WBA11AP04RCR41747    156500  ...       nan              nan
# ...                    ...       ...  ...       ...              ...
# 1674107               None   86400.0  ...        []              nan
# 1674108               None   37810.0  ...        []              nan
# 1674109               None   38880.0  ...        []              nan
# 1674110  LMXA14AFXRZ354445   64644.0  ...        []              nan
# 1674111               None  139175.0  ...        []              nan
#
#                                           autoDataResponse  \
# 0                                                      nan
# 1                                                      nan
# 2                                                      nan
# 3                                                      nan
# 4                                                      nan
# ...                                                    ...
# 1674107  {'vinDecoding': {'admeid': 34857, 'description...
# 1674108                                               None
# 1674109  {'vinDecoding': {'admeid': 25968, 'description...
# 1674110  {'make': 'FORTHING', 'model': 'T5 EVO', 'year'...
# 1674111  {'vinDecoding': {'admeid': 25961, 'description...
#
#         mortgageDocumentDate bodyTypeCode vehicleMileage ocrRCVerified  \
# 0                        nan          nan            nan           nan
# 1                        nan          nan            nan           nan
# 2                        nan          nan            nan           nan
# 3                        nan          nan            nan           nan
# 4                        nan          nan            nan           nan
# ...                      ...          ...            ...           ...
# 1674107                  nan          nan            1.0         False
# 1674108                  nan          nan            1.0         False
# 1674109                  nan          nan            1.0         False
# 1674110                  nan          nan            nan         False
# 1674111                  nan          nan            1.0         False
#
#         ocrVCCVerified ocrNCCVerified ocrPassingPaperVerified
# 0                  nan            nan                     nan
# 1                  nan            nan                     nan
# 2                  nan            nan                     nan
# 3                  nan            nan                     nan
# 4                  nan            nan                     nan
# ...                ...            ...                     ...
# 1674107          False          False                   False
# 1674108          False          False                   False
# 1674109          False          False                   False
# 1674110          False          False                   False
# 1674111          False          False                   False
#
# [1674112 rows x 76 columns]

# %%
for col in df.columns:
    print(col)
# Out:
# _id
# make
# model
# trim
# bodyType
# cylinders
# year
# insureType
# chassisNumber
# price
# origin
# yearOfNoClaim
# typeOfIssues
# claimHistory
# regionalSpec
# registrationCardP
# rcFrontCopyP
# newOwnerTcNumber
# vehicleClearanceCertificateP
# newCarCardP
# ownershipProofDocumentP
# passingPaperCardP
# passingDocInspectionDate
# responseOCRPassingPaper
# plateCode
# plateNumber
# tcNo
# policyEffectiveDate
# weightInKg
# weightInTons
# weightInGallons
# isBrandNew
# insuranceExpiryDate
# color
# currentInsurer
# isCurrentInsuranceActive
# engineNumber
# regCardExpiryDate
# registrationEmirate
# policyNumber
# noOfPassengers
# isCarEdited
# regenerate
# useOfVehicle
# valuation
# noOfDoors
# dateOfFirstRegister
# regCardName
# createdAt
# updatedAt
# chassisNumberStatus
# motorProduct
# declarationDate
# responseOCRRC
# engineSize
# originalPrice
# owner
# transmission
# autoDataPrice
# engineCapacity
# maxValue
# minValue
# mortgageBankName
# regCardNameAr
# applicantId
# userId
# carImages
# tradeLicenseName
# autoDataResponse
# mortgageDocumentDate
# bodyTypeCode
# vehicleMileage
# ocrRCVerified
# ocrVCCVerified
# ocrNCCVerified
# ocrPassingPaperVerified

# %%
df_methaq = df[["chassisNumber","year", "make", "model", 'trim', 'bodyType', 'regionalSpec', "cylinders", 'color', 'origin', 'weightInKg', "noOfPassengers"]]

# %%
df_methaq
# Out:
#              chassisNumber    year      make   model             trim  \
# 0        JTFHX02P7F0094323    2015    TOYOTA   HIACE               DX
# 1        JTFHX02P7F0094323    2015    TOYOTA   HIACE               DX
# 2        JTFHXDGP7F0094373    2015    TOYOTA   HILUX               DL
# 3        JN1ASNYC3PU200564    2024  INFINITI    QX50       LUXE STYLE
# 4        WBA11AP04RCR41747    2024       BMW    420I  M SPORT PREMIUM
# ...                    ...     ...       ...     ...              ...
# 1674107               None  2024.0    TOYOTA   HILUX             SGLX
# 1674108               None  2022.0        MG      GT           LUXURY
# 1674109               None  2020.0   HYUNDAI  TUCSON               GL
# 1674110  LMXA14AFXRZ354445  2024.0  FORTHING  T5 EVO        EXCLUSIVE
# 1674111               None  2020.0    NISSAN  PATROL  SUPER SAFARI HT
#
#                    bodyType regionalSpec cylinders  color   origin weightInKg  \
# 0        Mini Bus High Roof          GCC         4  white    Japan     1837.0
# 1        Mini Bus High Roof          GCC         4  white    Japan     1837.0
# 2        Pick Up Double Cab          GCC         4  white    Japan     1837.0
# 3                       SUV          GCC         4   grey   Mexico     1898.0
# 4                     COUPE          GCC         4  black  Germany     1525.0
# ...                     ...          ...       ...    ...      ...        ...
# 1674107  Pick Up Double Cab          GCC         4   None    Japan     3000.0
# 1674108               SEDAN          GCC         4   None    China     3000.0
# 1674109                 SUV      Non-GCC         4   None    Korea     3000.0
# 1674110                 SUV          GCC         4   grey    CHINA     1715.0
# 1674111                 SUV          GCC         6   None    Japan     3000.0
#
#         noOfPassengers
# 0                 15.0
# 1                 15.0
# 2                  5.0
# 3                  5.0
# 4                  4.0
# ...                ...
# 1674107            5.0
# 1674108            5.0
# 1674109            5.0
# 1674110            5.0
# 1674111            5.0
#
# [1674112 rows x 12 columns]

# %%
df_methaq.to_csv("../Data/df_methaq.csv", index=False)

# %%
df_methaq.to_json("../Data/df_methaq.json", orient="records", lines=True)

# %%
data = df_methaq[~df_methaq["chassisNumber"].isin(["None", None, np.nan])].copy()

# %%
data
# Out:
#              chassisNumber    year      make      model             trim  \
# 0        JTFHX02P7F0094323    2015    TOYOTA      HIACE               DX
# 1        JTFHX02P7F0094323    2015    TOYOTA      HIACE               DX
# 2        JTFHXDGP7F0094373    2015    TOYOTA      HILUX               DL
# 3        JN1ASNYC3PU200564    2024  INFINITI       QX50       LUXE STYLE
# 4        WBA11AP04RCR41747    2024       BMW       420I  M SPORT PREMIUM
# ...                    ...     ...       ...        ...              ...
# 1674102  WBAWX9107D0C73063  2013.0       BMW         X3       XDRIVE 28I
# 1674104  LSJA36U93SN031903  2025.0        MG         GT           LUXURY
# 1674105  LCOFD1C45S5434989  2025.0       BYD  LEOPARD 5    STD (NON GCC)
# 1674106  1N4AL3AP5FC217467  2015.0    NISSAN     ALTIMA               SL
# 1674110  LMXA14AFXRZ354445  2024.0  FORTHING     T5 EVO        EXCLUSIVE
#
#                    bodyType regionalSpec cylinders   color   origin  \
# 0        Mini Bus High Roof          GCC         4   white    Japan
# 1        Mini Bus High Roof          GCC         4   white    Japan
# 2        Pick Up Double Cab          GCC         4   white    Japan
# 3                       SUV          GCC         4    grey   Mexico
# 4                     COUPE          GCC         4   black  Germany
# ...                     ...          ...       ...     ...      ...
# 1674102                 SUV          GCC         6    None  Germany
# 1674104               SEDAN          GCC         4   black    China
# 1674105                 SUV          GCC         0   black    CHINA
# 1674106               SEDAN          GCC         4  silver  AMERICA
# 1674110                 SUV          GCC         4    grey    CHINA
#
#         weightInKg noOfPassengers
# 0           1837.0           15.0
# 1           1837.0           15.0
# 2           1837.0            5.0
# 3           1898.0            5.0
# 4           1525.0            4.0
# ...            ...            ...
# 1674102     3000.0            5.0
# 1674104     1600.0            5.0
# 1674105        nan            5.0
# 1674106     1600.0            5.0
# 1674110     1715.0            5.0
#
# [1572039 rows x 12 columns]

# %%
data = data.loc[data['make'].map(data['make'].value_counts()).sort_values(ascending=False).index]
data
# Out:
#              chassisNumber  year             make       model trim  \
# 8        RKLBB9HE7F5115863  2015           TOYOTA     COROLLA   SE
# 13       JTFHX02POF0099797  2015           TOYOTA       HIACE  GLX
# 0        JTFHX02P7F0094323  2015           TOYOTA       HIACE   DX
# 1        JTFHX02P7F0094323  2015           TOYOTA       HIACE   DX
# 2        JTFHXDGP7F0094373  2015           TOYOTA       HILUX   DL
# ...                    ...   ...              ...         ...  ...
# 125085   7KGTC2C48NR003646  2022  Electric Motion       ePure  nan
# 1036650  LM8F7D196PA000511  2023            NWONE        2023  STD
# 141407   LX6TK334XS2510023  2025        CHANGHUA    CH150T-34
# 134324          MI76734700  2015          MANITOU  MTX1740SLT   GL
# 275349   LK1PCKL94P1000940  2023       MOTORCYCLE      SY1507
#
#                    bodyType regionalSpec cylinders           color   origin  \
# 8                     SEDAN          GCC         4          silver   Taiwan
# 13       Mini Bus High Roof          GCC         4           white    Japan
# 0        Mini Bus High Roof          GCC         4           white    Japan
# 1        Mini Bus High Roof          GCC         4           white    Japan
# 2        Pick Up Double Cab          GCC         4           white    Japan
# ...                     ...          ...       ...             ...      ...
# 125085           Motorcycle          GCC       nan  gray and black  AMERICA
# 1036650             Station          GCC         6            blue    China
# 141407           Motorcycle          GCC            gray and black    China
# 134324      HEAVY EQUIPMENT          GCC         4            grey    Italy
# 275349           Motorcycle          GCC                     black    China
#
#         weightInKg noOfPassengers
# 8           1000.0            5.0
# 13          2000.0            2.0
# 0           1837.0           15.0
# 1           1837.0           15.0
# 2           1837.0            5.0
# ...            ...            ...
# 125085       450.0            2.0
# 1036650     1600.0            5.0
# 141407       150.0            2.0
# 134324     12000.0            1.0
# 275349       150.0            2.0
#
# [1572039 rows x 12 columns]

# %%
data.drop_duplicates(subset=['chassisNumber'], keep='first', inplace=True)

# %%
data
# Out:
#              chassisNumber    year             make            model trim  \
# 8        RKLBB9HE7F5115863    2015           TOYOTA          COROLLA   SE
# 13       JTFHX02POF0099797    2015           TOYOTA            HIACE  GLX
# 0        JTFHX02P7F0094323    2015           TOYOTA            HIACE   DX
# 2        JTFHXDGP7F0094373    2015           TOYOTA            HILUX   DL
# 14       4T1BG22K01U789089    2001           TOYOTA            CAMRY  XLI
# ...                    ...     ...              ...              ...  ...
# 1239327  LNGPCMXJ9PL305272  2023.0           APULUO  APULUO AP200 4H  nan
# 960544   LURJAVBM8PA024843    2023            AIQAR             EQ 1  STD
# 125085   7KGTC2C48NR003646    2022  Electric Motion            ePure  nan
# 141407   LX6TK334XS2510023    2025        CHANGHUA         CH150T-34
# 134324          MI76734700    2015          MANITOU       MTX1740SLT   GL
#
#                    bodyType regionalSpec cylinders            color   origin  \
# 8                     SEDAN          GCC         4           silver   Taiwan
# 13       Mini Bus High Roof          GCC         4            white    Japan
# 0        Mini Bus High Roof          GCC         4            white    Japan
# 2        Pick Up Double Cab          GCC         4            white    Japan
# 14                    SEDAN      Non-GCC         4  brown and beige    Japan
# ...                     ...          ...       ...              ...      ...
# 1239327          Motorcycle          GCC       nan            black    China
# 960544                COUPE          GCC         4             blue    CHINA
# 125085           Motorcycle          GCC       nan   gray and black  AMERICA
# 141407           Motorcycle          GCC             gray and black    China
# 134324      HEAVY EQUIPMENT          GCC         4             grey    Italy
#
#         weightInKg noOfPassengers
# 8           1000.0            5.0
# 13          2000.0            2.0
# 0           1837.0           15.0
# 2           1837.0            5.0
# 14          1481.0            5.0
# ...            ...            ...
# 1239327      150.0            2.0
# 960544         nan            2.0
# 125085       450.0            2.0
# 141407       150.0            2.0
# 134324     12000.0            1.0
#
# [1009604 rows x 12 columns]

# %%
# 1. Clean data: Using already cleaned 'data' (where chassisNumber is not None or "None")
print(f"Original shape: {df_methaq.shape}")
print(f"Cleaned shape: {data.shape}")
print(f"Dropped rows: {len(df_methaq) - len(data)}")
# Out:
# Original shape: (1674112, 12)
# Cleaned shape: (1009604, 12)
# Dropped rows: 664508

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Define all variations of missing/none/nan values
missing_indicators = [None, np.nan, 'None', 'none', 'nan', 'NaN', 'null', 'Null']

# 2. Count occurrences of these indicators across all columns
missing_counts = data.isin(missing_indicators).sum()
missing_percent = (missing_counts / len(data)) * 100

# 3. Create the missing values summary DataFrame
missing_df = pd.DataFrame({'Missing Counts': missing_counts, 'Percentage (%)': missing_percent})
print("--- Missing Values (including None and NaN strings) ---")
print(missing_df)

# 4. Plotting
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 5))
sns.barplot(
    x=missing_df.index, 
    y='Percentage (%)', 
    data=missing_df, 
    palette="viridis", 
    hue=missing_df.index, 
    legend=False
)
plt.title("Percentage of Missing/None Values per Column")
plt.xticks(rotation=45, ha='right')
plt.ylabel("Missing (%)")
plt.tight_layout()
plt.show()
# Out:
# --- Missing Values (including None and NaN strings) ---
#                 Missing Counts  Percentage (%)
# chassisNumber                0        0.000000
# year                         3        0.000297
# make                        11        0.001090
# model                        3        0.000297
# trim                     15918        1.576658
# bodyType                     1        0.000099
# regionalSpec               283        0.028031
# cylinders                15916        1.576460
# color                    63602        6.299698
# origin                   85018        8.420925
# weightInKg              102248       10.127535
# noOfPassengers               7        0.000693

# %%
# 3. EDA - Distribution of top 10 Car Makes
make_counts = data['make'].value_counts()
top_10_makes = make_counts.head(10)
print("--- Top 10 Vehicle Makes ---")
for make, count in top_10_makes.items():
    pct = (count / len(data)) * 100
    print(f"{make}: {count} ({pct:.2f}%)")

plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_makes.values, y=top_10_makes.index, palette="Blues_r", hue=top_10_makes.index, legend=False)
plt.title("Top 10 Vehicle Makes")
plt.xlabel("Count")
plt.ylabel("Make")
plt.show()
# Out:
# --- Top 10 Vehicle Makes ---
# TOYOTA: 241600 (23.93%)
# NISSAN: 205705 (20.37%)
# LEXUS: 63065 (6.25%)
# HONDA: 51394 (5.09%)
# MITSUBISHI: 50719 (5.02%)
# HYUNDAI: 43547 (4.31%)
# MERCEDES BENZ: 34155 (3.38%)
# KIA: 33798 (3.35%)
# CHEVROLET: 26826 (2.66%)
# FORD: 25360 (2.51%)

# %%
# 4. EDA - Manufacturing Year Distribution
data['year'] = pd.to_numeric(data['year'], errors='coerce')
year_df = data.dropna(subset=['year'])
print("--- Year Statistics ---")
print(year_df['year'].describe())

plt.figure(figsize=(12, 5))
filtered_years = year_df[(year_df['year'] >= 1980) & (year_df['year'] <= 2026)]['year']
sns.histplot(filtered_years, bins=30, kde=True, color="#4c72b0", edgecolor="white")
plt.title("Distribution of Vehicle Manufacturing Years (1980 - 2026)")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()
# Out:
# --- Year Statistics ---
# count    1.009593e+06
# mean     2.014286e+03
# std      6.636356e+00
# min      1.929000e+03
# 25%      2.009000e+03
# 50%      2.015000e+03
# 75%      2.019000e+03
# max      2.028000e+03
# Name: year, dtype: float64

# %%
# 5. EDA - Distribution of top 10 Body Types
body_type_counts = data['bodyType'].value_counts()
top_10_body = body_type_counts.head(10)
print("--- Top 10 Body Types ---")
for bt, count in top_10_body.items():
    pct = (count / len(data)) * 100
    print(f"{bt}: {count} ({pct:.2f}%)")

plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_body.values, y=top_10_body.index, palette="magma", hue=top_10_body.index, legend=False)
plt.title("Top 10 Vehicle Body Types")
plt.xlabel("Count")
plt.ylabel("Body Type")
plt.show()
# Out:
# --- Top 10 Body Types ---
# SEDAN: 413805 (40.99%)
# SUV: 360631 (35.72%)
# HATCHBACK: 66640 (6.60%)
# Pick Up Double Cab: 26760 (2.65%)
# Pick Up: 21303 (2.11%)
# MPV: 20885 (2.07%)
# Motorcycle: 17730 (1.76%)
# COUPE: 16772 (1.66%)
# Pick Up Single Cab: 11228 (1.11%)
# Mini Bus: 8464 (0.84%)

# %%
# 6. EDA - Engine Cylinders
data['cylinders'] = pd.to_numeric(data['cylinders'], errors='coerce')
cylinder_counts = data['cylinders'].value_counts().sort_index()
print("--- Cylinders Distribution ---")
print(cylinder_counts)

plt.figure(figsize=(10, 5))
sns.countplot(data=data, x='cylinders', palette="rocket", order=cylinder_counts.index, hue='cylinders', legend=False)
plt.title("Distribution of Engine Cylinders")
plt.xlabel("Cylinders")
plt.ylabel("Count")
plt.show()
# Out:
# --- Cylinders Distribution ---
# cylinders
# 0.0      17597
# 2.0          1
# 3.0       8989
# 4.0     608892
# 5.0       1641
# 6.0     210942
# 8.0     140251
# 9.0         98
# 10.0       203
# 12.0      2281
# 16.0        22
# Name: count, dtype: int64

# %%
# 7. EDA - Regional Specifications
regional_counts = data['regionalSpec'].value_counts()
print("--- Regional Specs Distribution ---")
print(regional_counts)

plt.figure(figsize=(8, 8))
plt.pie(regional_counts.values, labels=regional_counts.index, autopct='%1.1f%%', 
        colors=sns.color_palette("pastel")[0:len(regional_counts)], startangle=140,
        wedgeprops={'edgecolor': 'white', 'linewidth': 1.5})
plt.title("Distribution of Regional Specifications")
plt.show()
# Out:
# --- Regional Specs Distribution ---
# regionalSpec
# GCC        985446
# Non-GCC     23875
# None          280
# nan             3
# Name: count, dtype: int64

# %%
data
# Out:
#              chassisNumber    year             make            model trim  \
# 8        RKLBB9HE7F5115863  2015.0           TOYOTA          COROLLA   SE
# 13       JTFHX02POF0099797  2015.0           TOYOTA            HIACE  GLX
# 0        JTFHX02P7F0094323  2015.0           TOYOTA            HIACE   DX
# 2        JTFHXDGP7F0094373  2015.0           TOYOTA            HILUX   DL
# 14       4T1BG22K01U789089  2001.0           TOYOTA            CAMRY  XLI
# ...                    ...     ...              ...              ...  ...
# 1239327  LNGPCMXJ9PL305272  2023.0           APULUO  APULUO AP200 4H  nan
# 960544   LURJAVBM8PA024843  2023.0            AIQAR             EQ 1  STD
# 125085   7KGTC2C48NR003646  2022.0  Electric Motion            ePure  nan
# 141407   LX6TK334XS2510023  2025.0        CHANGHUA         CH150T-34
# 134324          MI76734700  2015.0          MANITOU       MTX1740SLT   GL
#
#                    bodyType regionalSpec  cylinders            color   origin  \
# 8                     SEDAN          GCC        4.0           silver   Taiwan
# 13       Mini Bus High Roof          GCC        4.0            white    Japan
# 0        Mini Bus High Roof          GCC        4.0            white    Japan
# 2        Pick Up Double Cab          GCC        4.0            white    Japan
# 14                    SEDAN      Non-GCC        4.0  brown and beige    Japan
# ...                     ...          ...        ...              ...      ...
# 1239327          Motorcycle          GCC        NaN            black    China
# 960544                COUPE          GCC        4.0             blue    CHINA
# 125085           Motorcycle          GCC        NaN   gray and black  AMERICA
# 141407           Motorcycle          GCC        NaN   gray and black    China
# 134324      HEAVY EQUIPMENT          GCC        4.0             grey    Italy
#
#         weightInKg noOfPassengers
# 8           1000.0            5.0
# 13          2000.0            2.0
# 0           1837.0           15.0
# 2           1837.0            5.0
# 14          1481.0            5.0
# ...            ...            ...
# 1239327      150.0            2.0
# 960544         nan            2.0
# 125085       450.0            2.0
# 141407       150.0            2.0
# 134324     12000.0            1.0
#
# [1009604 rows x 12 columns]

# %%
data.to_csv("../Data/data_methaq(2.0).csv", index=False)
