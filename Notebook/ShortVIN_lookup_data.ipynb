# %%
import pandas as pd

# %%
# 1. Load your dataset (replace with your actual file path/method)
df = pd.read_csv("../Data/final_clean_ShortVIN.csv")

# %%
df
# Out:
#        chassisNumber    year        make           model                 trim  \
# 0          4B0189130  1993.0      TOYOTA         COROLLA                   LE
# 1       EE1004019201  1993.0      TOYOTA         COROLLA                   LE
# 2       ZGE216016857  2010.0      TOYOTA            RAV4                 BASE
# 3         NV18008048  2005.0      TOYOTA           CAMRY                  XLI
# 4         NV18056527  2004.0      TOYOTA           CAMRY                  GLI
# ...              ...     ...         ...             ...                  ...
# 13268     4520016452  1978.0         NaN  CRANE/MAN26280  CTTO CRANE/MAN26280
# 13269  344870M169272  1970.0  OLDSMOBILE             NaN                  STD
# 13270   FK415KB30502  1996.0         NaN             NaN                  GLE
# 13271    SG20J014379  2015.0      YAMAHA         MAJESTY                  NaN
# 13272     MI76734700  2015.0     MANITOU      MTX1740SLT                   GL
#
# ...

# %%
# 2. Define your 4 priority columns
priority_cols = ["year", "make", "model", "trim"]

# %%
# 3. Drop duplicates based ONLY on those 4 columns, keeping the first occurrence
df_cleaned = df.drop_duplicates(subset=priority_cols, keep="first")

# %%
# 4. Save or view your cleaned dataset
df_cleaned
# Out:
#        chassisNumber    year        make           model                 trim  \
# 0          4B0189130  1993.0      TOYOTA         COROLLA                   LE
# 2       ZGE216016857  2010.0      TOYOTA            RAV4                 BASE
# 3         NV18008048  2005.0      TOYOTA           CAMRY                  XLI
# 4         NV18056527  2004.0      TOYOTA           CAMRY                  GLI
# 5         NV18087272  2005.0      TOYOTA           CAMRY                  GLI
# ...              ...     ...         ...             ...                  ...
# 13267  2S87U8N135556  1978.0         NaN             NaN                 BASE
# 13268     4520016452  1978.0         NaN  CRANE/MAN26280  CTTO CRANE/MAN26280
# 13269  344870M169272  1970.0  OLDSMOBILE             NaN                  STD
# 13270   FK415KB30502  1996.0         NaN             NaN                  GLE
# 13272     MI76734700  2015.0     MANITOU      MTX1740SLT                   GL
#
# ...

# %%
df_cleaned.to_csv("../Data/final_clean_ShortVIN_lookup_data.csv", index=False)
