# %%
import pandas as pd

# %%
data1 = pd.read_csv(r'..\Data\master_data.csv')

# %%
data2 = pd.read_csv(r'..\Data\data_methaq(1.0).csv')

# %%
merged_df = pd.concat([data1, data2], ignore_index=True)

# %%
merged_df
# Out:
#                trim  cylinders             make            model    year  \
# 0         Adventure        4.0              212              T01  2026.0
# 1        Adventurer        4.0              212              T01  2024.0
# 2            Falcon        4.0              212              T01  2024.0
# 3           Pioneer        4.0              212              T01  2024.0
# 4          Standard        0.0             AION          AION ES  2024.0
# ...             ...        ...              ...              ...     ...
# 1072410         NaN        NaN           APULUO  APULUO AP200 4H  2023.0
# 1072411         STD        4.0            AIQAR             EQ 1  2023.0
# 1072412         NaN        NaN  Electric Motion            ePure  2022.0
# 1072413         NaN        NaN        CHANGHUA         CH150T-34  2025.0
# 1072414          GL        4.0          MANITOU       MTX1740SLT  2015.0
#
#                 bodyType regionalSpec  noOfDoors   origin      chassisNumber
# ...

# %%
merged_df.to_csv("../Data/mergedd_data.csv", index=False)
