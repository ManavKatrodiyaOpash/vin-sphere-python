# %%
import pandas as pd

# %%
data = pd.read_csv("../car_app_dev/cleaned_dataset.csv")

# %%
data
# Out:
#             chassisNumber    year             make trim            bodyType  \
# 0       RKLBB9HE7F5115863  2015.0           TOYOTA   SE               SEDAN
# 1       JTFHX02POF0099797  2015.0           TOYOTA  GLX  Mini Bus High Roof
# 2       JTFHX02P7F0094323  2015.0           TOYOTA   DX  Mini Bus High Roof
# 3       JTFHXDGP7F0094373  2015.0           TOYOTA   DL  Pick Up Double Cab
# 4       4T1BG22K01U789089  2001.0           TOYOTA  XLI               SEDAN
# ...                   ...     ...              ...  ...                 ...
# 995042  HY2PEAND0PB000238  2023.0           BIMOTA  NaN          Motorcycle
# 995043  LNGPCMXJ9PL305272  2023.0           APULUO  NaN          Motorcycle
# 995044  LURJAVBM8PA024843  2023.0            CHERY  STD               COUPE
# 995045  7KGTC2C48NR003646  2022.0  ELECTRIC MOTION  NaN          Motorcycle
# 995046  LX6TK334XS2510023  2025.0         CHANGHUA  NaN          Motorcycle
#
# ...
